# %% [markdown]
# # Import required packages for model

# %%
## To get audio file paths, listdir, walk
import os
## To replace filenames, data cleaning
import re
# Work with folder/file paths
import pathlib
# To allow for random audio samples
import random
# Python math
import numpy as np
# Audio loading and processing
import librosa
import librosa.display
# plotting diagrams
import matplotlib
import matplotlib.pyplot as plt
# For the ML model, audio processing
import tensorflow as tf
from tensorflow.keras import layers, models
# For building models
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Create data paths, test and train folders

# %%
DATASET_PATH = r"C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data"
train_dir = pathlib.Path(f'{DATASET_PATH}/Training')
test_dir = pathlib.Path(f'{DATASET_PATH}/Test')
test_folder_names = np.array(tf.io.gfile.listdir(str(test_dir))) # ['Am' 'Bb' 'Bdim' 'C' 'Dm' 'Em' 'F' 'G']
train_folder_names = np.array(tf.io.gfile.listdir(str(train_dir))) # ['Am' 'Bb' 'Bdim' 'C' 'Dm' 'Em' 'F' 'G']

if not train_dir.exists():
    print("Training path does not exist. Please check dataset location.")

if not test_dir.exists():
    print("Test path does not exist. Please check dataset location.")

print(test_folder_names)
print(train_folder_names)

print(train_dir)
print(test_dir)
# Out:
# ['Am' 'Bb' 'Bdim' 'C' 'Dm' 'Em' 'F' 'G']
# ['Am' 'Bb' 'Bdim' 'C' 'Dm' 'Em' 'F' 'G']
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test

# %% [markdown]
# # Preliminary dataset - unsanitized dataset names

# %%
def list_audios_with_path(base_path, folder_names):
    # An array of paths the each folder in Training
    folder_paths = [os.path.join(base_path, folderName) for folderName in folder_names if os.path.isdir(os.path.join(base_path, folderName))]
    
    # loop through every path, get every .wav in each foler add to array file_names[]
    result = {}
    for path in folder_paths:
        file_names = []
        for root, dirs, files in os.walk(path):
            for name in files:
                file_names.append(name)
            #path will be the key in each result dictionary
            result[path] = file_names
    return result

train_result = list_audios_with_path(train_dir, train_folder_names)
for path, files in train_result.items():
    print(f"\n {path}")
    print(files)
        

test_result = list_audios_with_path(test_dir, test_folder_names)
for path, files in test_result.items():
    print(f"\n {path}")
    print(files)
# Out:
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Am
# ['Am_acousticguitar_Mari_1.wav', 'Am_acousticguitar_Mari_2.wav', 'Am_acousticguitar_Mari_3.wav', 'Am_acousticguitar_Mari_4.wav', 'Am_acousticguitar_SalomCΓòá┬║Andrade_1.wav', 'Am_acousticguitar_SalomCΓòá┬║Andrade_2.wav', 'Am_acousticguitar_SalomCΓòá┬║Andrade_3.wav', 'Am_acousticguitar_SalomCΓòá┬║Andrade_4.wav', 'Am_acusticGB_JO_1.wav', 'Am_acusticGB_JO_2.wav', 'Am_acusticGB_JO_3.wav', 'Am_acusticGB_JO_4.wav', 'Am_AcusticPlug15_1.wav', 'Am_AcusticPlug15_2.wav', 'Am_AcusticPlug15_3.wav', 'Am_AcusticPlug15_4.wav', 'Am_AcusticPlug16_1.wav', 'Am_AcusticPlug16_2.wav', 'Am_AcusticPlug16_3.wav', 'Am_AcusticPlug16_4.wav', 'Am_AcusticPlug17_1.wav', 'Am_AcusticPlug17_2.wav', 'Am_AcusticPlug17_3.wav', 'Am_AcusticPlug17_4.wav', 'Am_AcusticPlug18_1.wav', 'Am_AcusticPlug18_2.wav', 'Am_AcusticPlug18_3.wav', 'Am_AcusticPlug18_4.wav', 'Am_AcusticPlug19_1.wav', 'Am_AcusticPlug19_2.wav', 'Am_AcusticPlug19_3.wav', 'Am_AcusticPlug19_4.wav', 'Am_AcusticPlug1_1.wav', 'Am_AcusticPlug1_2.wav', 'Am_AcusticPlug1_3.wav', 'Am_AcusticPlug1_4.wav', 'Am_AcusticPlug20_1.wav', 'Am_AcusticPlug20_2.wav', 'Am_AcusticPlug20_3.wav', 'Am_AcusticPlug20_4.wav', 'Am_AcusticPlug21_1.wav', 'Am_AcusticPlug21_2.wav', 'Am_AcusticPlug21_3.wav', 'Am_AcusticPlug21_4.wav', 'Am_AcusticPlug22_1.wav', 'Am_AcusticPlug22_2.wav', 'Am_AcusticPlug22_3.wav', 'Am_AcusticPlug22_4.wav', 'Am_AcusticPlug23_1.wav', 'Am_AcusticPlug23_2.wav', 'Am_AcusticPlug23_3.wav', 'Am_AcusticPlug23_4.wav', 'Am_AcusticPlug24_1.wav', 'Am_AcusticPlug24_2.wav', 'Am_AcusticPlug24_3.wav', 'Am_AcusticPlug24_4.wav', 'Am_AcusticPlug25_1.wav', 'Am_AcusticPlug25_2.wav', 'Am_AcusticPlug25_3.wav', 'Am_AcusticPlug25_4.wav', 'Am_AcusticPlug26_1.wav', 'Am_AcusticPlug26_2.wav', 'Am_AcusticPlug26_3.wav', 'Am_AcusticPlug26_4.wav', 'Am_AcusticPlug27_1.wav', 'Am_AcusticPlug27_2.wav', 'Am_AcusticPlug27_3.wav', 'Am_AcusticPlug27_4.wav', 'Am_AcusticPlug28_1.wav', 'Am_AcusticPlug28_2.wav', 'Am_AcusticPlug28_3.wav', 'Am_AcusticPlug28_4.wav', 'Am_AcusticPlug29_1.wav', 'Am_AcusticPlug29_2.wav', 'Am_AcusticPlug29_3.wav', 'Am_AcusticPlug29_4.wav', 'Am_AcusticPlug2_1.wav', 'Am_AcusticPlug2_2.wav', 'Am_AcusticPlug2_3.wav', 'Am_AcusticPlug2_4.wav', 'Am_AcusticPlug30_1.wav', 'Am_AcusticPlug30_2.wav', 'Am_AcusticPlug30_3.wav', 'Am_AcusticPlug30_4.wav', 'Am_AcusticPlug3_1.wav', 'Am_AcusticPlug3_2.wav', 'Am_AcusticPlug3_3.wav', 'Am_AcusticPlug3_4.wav', 'Am_AcusticPlug4_1.wav', 'Am_AcusticPlug4_2.wav', 'Am_AcusticPlug4_3.wav', 'Am_AcusticPlug4_4.wav', 'Am_AcusticPlug5_1.wav', 'Am_AcusticPlug5_2.wav', 'Am_AcusticPlug5_3.wav', 'Am_AcusticPlug5_4.wav', 'Am_AcusticPlug7_1.wav', 'Am_AcusticPlug7_2.wav', 'Am_AcusticPlug7_3.wav', 'Am_AcusticPlug7_4.wav', 'Am_Acustic_Miguel_1.wav', 'Am_Acustic_Miguel_2.wav', 'Am_Acustic_Miguel_3.wav', 'Am_Acustic_Miguel_4.wav', 'Am_AcustiicPlug10_1.wav', 'Am_AcustiicPlug10_2.wav', 'Am_AcustiicPlug10_3.wav', 'Am_AcustiicPlug10_4.wav', 'Am_AcustiicPlug11_1.wav', 'Am_AcustiicPlug11_2.wav', 'Am_AcustiicPlug11_3.wav', 'Am_AcustiicPlug11_4.wav', 'Am_AcustiicPlug12_1.wav', 'Am_AcustiicPlug12_2.wav', 'Am_AcustiicPlug12_3.wav', 'Am_AcustiicPlug12_4.wav', 'Am_AcustiicPlug13_1.wav', 'Am_AcustiicPlug13_2.wav', 'Am_AcustiicPlug13_3.wav', 'Am_AcustiicPlug13_4.wav', 'Am_AcustiicPlug14_1.wav', 'Am_AcustiicPlug14_2.wav', 'Am_AcustiicPlug14_3.wav', 'Am_AcustiicPlug14_4.wav', 'Am_AcustiicPlug6_1.wav', 'Am_AcustiicPlug6_2.wav', 'Am_AcustiicPlug6_3.wav', 'Am_AcustiicPlug6_4.wav', 'Am_AcustiicPlug8_1.wav', 'Am_AcustiicPlug8_2.wav', 'Am_AcustiicPlug8_3.wav', 'Am_AcustiicPlug8_4.wav', 'Am_AcustiicPlug9_1.wav', 'Am_AcustiicPlug9_2.wav', 'Am_AcustiicPlug9_3.wav', 'Am_AcustiicPlug9_4.wav', 'Am_classical_henrique_1.wav', 'Am_classical_henrique_2.wav', 'Am_classical_henrique_3.wav', 'Am_classical_henrique_4.wav', 'Am_ClassicA_Miguel_1.wav', 'Am_ClassicA_Miguel_2.wav', 'Am_ClassicA_Miguel_3.wav', 'Am_ClassicA_Miguel_4.wav', 'Am_ClassicCleanGB_JO_1.wav', 'Am_ClassicCleanGB_JO_2.wav', 'Am_ClassicCleanGB_JO_3.wav', 'Am_ClassicCleanGB_JO_4.wav', 'Am_Cla ...
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Bb
# ['Bb_acousticguitar_Mari_1.wav', 'Bb_acousticguitar_Mari_2.wav', 'Bb_acousticguitar_Mari_3.wav', 'Bb_acousticguitar_Mari_4.wav', 'Bb_acousticguitar_SalomCΓòá┬║Andrade_1.wav', 'Bb_acousticguitar_SalomCΓòá┬║Andrade_2.wav', 'Bb_acousticguitar_SalomCΓòá┬║Andrade_3.wav', 'Bb_acousticguitar_SalomCΓòá┬║Andrade_4.wav', 'Bb_acusticGB_JO_1.wav', 'Bb_acusticGB_JO_2.wav', 'Bb_acusticGB_JO_3.wav', 'Bb_acusticGB_JO_4.wav', 'Bb_AcusticPlug10_1.wav', 'Bb_AcusticPlug10_2.wav', 'Bb_AcusticPlug10_3.wav', 'Bb_AcusticPlug10_4.wav', 'Bb_AcusticPlug11_1.wav', 'Bb_AcusticPlug11_2.wav', 'Bb_AcusticPlug11_3.wav', 'Bb_AcusticPlug11_4.wav', 'Bb_AcusticPlug12_1.wav', 'Bb_AcusticPlug12_2.wav', 'Bb_AcusticPlug12_3.wav', 'Bb_AcusticPlug12_4.wav', 'Bb_AcusticPlug13_1.wav', 'Bb_AcusticPlug13_2.wav', 'Bb_AcusticPlug13_3.wav', 'Bb_AcusticPlug13_4.wav', 'Bb_AcusticPlug14_1.wav', 'Bb_AcusticPlug14_2.wav', 'Bb_AcusticPlug14_3.wav', 'Bb_AcusticPlug14_4.wav', 'Bb_AcusticPlug15_1.wav', 'Bb_AcusticPlug15_2.wav', 'Bb_AcusticPlug15_3.wav', 'Bb_AcusticPlug15_4.wav', 'Bb_AcusticPlug16_1.wav', 'Bb_AcusticPlug16_2.wav', 'Bb_AcusticPlug16_3.wav', 'Bb_AcusticPlug16_4.wav', 'Bb_AcusticPlug17_1.wav', 'Bb_AcusticPlug17_2.wav', 'Bb_AcusticPlug17_3.wav', 'Bb_AcusticPlug17_4.wav', 'Bb_AcusticPlug18_1.wav', 'Bb_AcusticPlug18_2.wav', 'Bb_AcusticPlug18_3.wav', 'Bb_AcusticPlug18_4.wav', 'Bb_AcusticPlug19_1.wav', 'Bb_AcusticPlug19_2.wav', 'Bb_AcusticPlug19_3.wav', 'Bb_AcusticPlug19_4.wav', 'Bb_AcusticPlug1_1.wav', 'Bb_AcusticPlug1_2.wav', 'Bb_AcusticPlug1_3.wav', 'Bb_AcusticPlug1_4.wav', 'Bb_AcusticPlug20_1.wav', 'Bb_AcusticPlug20_2.wav', 'Bb_AcusticPlug20_3.wav', 'Bb_AcusticPlug20_4.wav', 'Bb_AcusticPlug21_1.wav', 'Bb_AcusticPlug21_2.wav', 'Bb_AcusticPlug21_3.wav', 'Bb_AcusticPlug21_4.wav', 'Bb_AcusticPlug22_1.wav', 'Bb_AcusticPlug22_2.wav', 'Bb_AcusticPlug22_3.wav', 'Bb_AcusticPlug22_4.wav', 'Bb_AcusticPlug23_1.wav', 'Bb_AcusticPlug23_2.wav', 'Bb_AcusticPlug23_3.wav', 'Bb_AcusticPlug23_4.wav', 'Bb_AcusticPlug24_1.wav', 'Bb_AcusticPlug24_2.wav', 'Bb_AcusticPlug24_3.wav', 'Bb_AcusticPlug24_4.wav', 'Bb_AcusticPlug25_1.wav', 'Bb_AcusticPlug25_2.wav', 'Bb_AcusticPlug25_3.wav', 'Bb_AcusticPlug25_4.wav', 'Bb_AcusticPlug26_1.wav', 'Bb_AcusticPlug26_2.wav', 'Bb_AcusticPlug26_3.wav', 'Bb_AcusticPlug26_4.wav', 'Bb_AcusticPlug27_1.wav', 'Bb_AcusticPlug27_2.wav', 'Bb_AcusticPlug27_3.wav', 'Bb_AcusticPlug27_4.wav', 'Bb_AcusticPlug28_1.wav', 'Bb_AcusticPlug28_2.wav', 'Bb_AcusticPlug28_3.wav', 'Bb_AcusticPlug28_4.wav', 'Bb_AcusticPlug29_1.wav', 'Bb_AcusticPlug29_2.wav', 'Bb_AcusticPlug29_3.wav', 'Bb_AcusticPlug29_4.wav', 'Bb_AcusticPlug2_1.wav', 'Bb_AcusticPlug2_2.wav', 'Bb_AcusticPlug2_3.wav', 'Bb_AcusticPlug2_4.wav', 'Bb_AcusticPlug30_1.wav', 'Bb_AcusticPlug30_2.wav', 'Bb_AcusticPlug30_3.wav', 'Bb_AcusticPlug30_4.wav', 'Bb_AcusticPlug3_1.wav', 'Bb_AcusticPlug3_2.wav', 'Bb_AcusticPlug3_3.wav', 'Bb_AcusticPlug3_4.wav', 'Bb_AcusticPlug4_1.wav', 'Bb_AcusticPlug4_2.wav', 'Bb_AcusticPlug4_3.wav', 'Bb_AcusticPlug4_4.wav', 'Bb_AcusticPlug5_1.wav', 'Bb_AcusticPlug5_2.wav', 'Bb_AcusticPlug5_3.wav', 'Bb_AcusticPlug5_4.wav', 'Bb_AcusticPlug6_1.wav', 'Bb_AcusticPlug6_2.wav', 'Bb_AcusticPlug6_3.wav', 'Bb_AcusticPlug6_4.wav', 'Bb_AcusticPlug7_1.wav', 'Bb_AcusticPlug7_2.wav', 'Bb_AcusticPlug7_3.wav', 'Bb_AcusticPlug7_4.wav', 'Bb_AcusticPlug8_1.wav', 'Bb_AcusticPlug8_2.wav', 'Bb_AcusticPlug8_3.wav', 'Bb_AcusticPlug8_4.wav', 'Bb_AcusticPlug9_1.wav', 'Bb_AcusticPlug9_2.wav', 'Bb_AcusticPlug9_3.wav', 'Bb_AcusticPlug9_4.wav', 'Bb_Acustic_Miguel_1.wav', 'Bb_Acustic_Miguel_2.wav', 'Bb_Acustic_Miguel_3.wav', 'Bb_Acustic_Miguel_4.wav', 'Bb_classical_henrique_1.wav', 'Bb_classical_henrique_2.wav', 'Bb_classical_henrique_3.wav', 'Bb_classical_henrique_4.wav', 'Bb_ClassicA_Miguel_1.wav', 'Bb_ClassicA_Miguel_2.wav', 'Bb_ClassicA_Miguel_3.wav', 'Bb_ClassicA_Miguel_4.wav', 'Bb_ClassicCleanGB_JO_1.wav', 'Bb_ClassicCleanGB_JO_2.wav', 'Bb_ClassicCleanGB_JO_3.wav', 'Bb_ClassicCleanGB_JO_4.wav', 'Bb_Classic_Jegundo_1.wav', 'Bb_Classic ...
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Bdim
# ['Bdim_acousticguitar_Mari_1.wav', 'Bdim_acousticguitar_Mari_2.wav', 'Bdim_acousticguitar_Mari_3.wav', 'Bdim_acousticguitar_Mari_4.wav', 'Bdim_acousticguitar_SalomCΓòá┬║Andrade_1.wav', 'Bdim_acousticguitar_SalomCΓòá┬║Andrade_2.wav', 'Bdim_acousticguitar_SalomCΓòá┬║Andrade_3.wav', 'Bdim_acousticguitar_SalomCΓòá┬║Andrade_4.wav', 'Bdim_acusticGB_JO_1.wav', 'Bdim_acusticGB_JO_2.wav', 'Bdim_acusticGB_JO_3.wav', 'Bdim_acusticGB_JO_4.wav', 'Bdim_AcusticPlug10_1.wav', 'Bdim_AcusticPlug10_2.wav', 'Bdim_AcusticPlug10_3.wav', 'Bdim_AcusticPlug10_4.wav', 'Bdim_AcusticPlug11_1.wav', 'Bdim_AcusticPlug11_2.wav', 'Bdim_AcusticPlug11_3.wav', 'Bdim_AcusticPlug11_4.wav', 'Bdim_AcusticPlug12_1.wav', 'Bdim_AcusticPlug12_2.wav', 'Bdim_AcusticPlug12_3.wav', 'Bdim_AcusticPlug12_4.wav', 'Bdim_AcusticPlug13_1.wav', 'Bdim_AcusticPlug13_2.wav', 'Bdim_AcusticPlug13_3.wav', 'Bdim_AcusticPlug13_4.wav', 'Bdim_AcusticPlug14_1.wav', 'Bdim_AcusticPlug14_2.wav', 'Bdim_AcusticPlug14_3.wav', 'Bdim_AcusticPlug14_4.wav', 'Bdim_AcusticPlug15_1.wav', 'Bdim_AcusticPlug15_2.wav', 'Bdim_AcusticPlug15_3.wav', 'Bdim_AcusticPlug15_4.wav', 'Bdim_AcusticPlug16_1.wav', 'Bdim_AcusticPlug16_2.wav', 'Bdim_AcusticPlug16_3.wav', 'Bdim_AcusticPlug16_4.wav', 'Bdim_AcusticPlug17_1.wav', 'Bdim_AcusticPlug17_2.wav', 'Bdim_AcusticPlug17_3.wav', 'Bdim_AcusticPlug17_4.wav', 'Bdim_AcusticPlug18_1.wav', 'Bdim_AcusticPlug18_2.wav', 'Bdim_AcusticPlug18_3.wav', 'Bdim_AcusticPlug18_4.wav', 'Bdim_AcusticPlug19_1.wav', 'Bdim_AcusticPlug19_2.wav', 'Bdim_AcusticPlug19_3.wav', 'Bdim_AcusticPlug19_4.wav', 'Bdim_AcusticPlug1_1.wav', 'Bdim_AcusticPlug1_2.wav', 'Bdim_AcusticPlug1_3.wav', 'Bdim_AcusticPlug1_4.wav', 'Bdim_AcusticPlug20_1.wav', 'Bdim_AcusticPlug20_2.wav', 'Bdim_AcusticPlug20_3.wav', 'Bdim_AcusticPlug20_4.wav', 'Bdim_AcusticPlug21_1.wav', 'Bdim_AcusticPlug21_2.wav', 'Bdim_AcusticPlug21_3.wav', 'Bdim_AcusticPlug21_4.wav', 'Bdim_AcusticPlug22_1.wav', 'Bdim_AcusticPlug22_2.wav', 'Bdim_AcusticPlug22_3.wav', 'Bdim_AcusticPlug22_4.wav', 'Bdim_AcusticPlug23_1.wav', 'Bdim_AcusticPlug23_2.wav', 'Bdim_AcusticPlug23_3.wav', 'Bdim_AcusticPlug23_4.wav', 'Bdim_AcusticPlug24_1.wav', 'Bdim_AcusticPlug24_2.wav', 'Bdim_AcusticPlug24_3.wav', 'Bdim_AcusticPlug24_4.wav', 'Bdim_AcusticPlug25_1.wav', 'Bdim_AcusticPlug25_2.wav', 'Bdim_AcusticPlug25_3.wav', 'Bdim_AcusticPlug25_4.wav', 'Bdim_AcusticPlug26_1.wav', 'Bdim_AcusticPlug26_2.wav', 'Bdim_AcusticPlug26_3.wav', 'Bdim_AcusticPlug26_4.wav', 'Bdim_AcusticPlug27_1.wav', 'Bdim_AcusticPlug27_2.wav', 'Bdim_AcusticPlug27_3.wav', 'Bdim_AcusticPlug27_4.wav', 'Bdim_AcusticPlug28_1.wav', 'Bdim_AcusticPlug28_2.wav', 'Bdim_AcusticPlug28_3.wav', 'Bdim_AcusticPlug28_4.wav', 'Bdim_AcusticPlug29_1.wav', 'Bdim_AcusticPlug29_2.wav', 'Bdim_AcusticPlug29_3.wav', 'Bdim_AcusticPlug29_4.wav', 'Bdim_AcusticPlug2_1.wav', 'Bdim_AcusticPlug2_2.wav', 'Bdim_AcusticPlug2_3.wav', 'Bdim_AcusticPlug2_4.wav', 'Bdim_AcusticPlug30_1.wav', 'Bdim_AcusticPlug30_2.wav', 'Bdim_AcusticPlug30_3.wav', 'Bdim_AcusticPlug30_4.wav', 'Bdim_AcusticPlug3_1.wav', 'Bdim_AcusticPlug3_2.wav', 'Bdim_AcusticPlug3_3.wav', 'Bdim_AcusticPlug3_4.wav', 'Bdim_AcusticPlug4_1.wav', 'Bdim_AcusticPlug4_2.wav', 'Bdim_AcusticPlug4_3.wav', 'Bdim_AcusticPlug4_4.wav', 'Bdim_AcusticPlug5_1.wav', 'Bdim_AcusticPlug5_2.wav', 'Bdim_AcusticPlug5_3.wav', 'Bdim_AcusticPlug5_4.wav', 'Bdim_AcusticPlug6_1.wav', 'Bdim_AcusticPlug6_2.wav', 'Bdim_AcusticPlug6_3.wav', 'Bdim_AcusticPlug6_4.wav', 'Bdim_AcusticPlug7_1.wav', 'Bdim_AcusticPlug7_2.wav', 'Bdim_AcusticPlug7_3.wav', 'Bdim_AcusticPlug7_4.wav', 'Bdim_AcusticPlug8_1.wav', 'Bdim_AcusticPlug8_2.wav', 'Bdim_AcusticPlug8_3.wav', 'Bdim_AcusticPlug8_4.wav', 'Bdim_AcusticPlug9_1.wav', 'Bdim_AcusticPlug9_2.wav', 'Bdim_AcusticPlug9_3.wav', 'Bdim_AcusticPlug9_4.wav', 'Bdim_Acustic_Miguel_1.wav', 'Bdim_Acustic_Miguel_2.wav', 'Bdim_Acustic_Miguel_3.wav', 'Bdim_Acustic_Miguel_4.wav', 'Bdim_classical_henrique_1.wav', 'Bdim_classical_henrique_2.wav', 'Bdim_classical_henrique_3.wav', 'Bdim_classical_henrique ...
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\C
# ['C_acousticguitar_Mari_1.wav', 'C_acousticguitar_Mari_2.wav', 'C_acousticguitar_Mari_3.wav', 'C_acousticguitar_Mari_4.wav', 'C_acousticguitar_SalomCΓòá┬║Andrade_1.wav', 'C_acousticguitar_SalomCΓòá┬║Andrade_2.wav', 'C_acousticguitar_SalomCΓòá┬║Andrade_3.wav', 'C_acousticguitar_SalomCΓòá┬║Andrade_4.wav', 'C_acusticGB_JO_1.wav', 'C_acusticGB_JO_2.wav', 'C_acusticGB_JO_3.wav', 'C_acusticGB_JO_4.wav', 'C_AcusticPlug10_1.wav', 'C_AcusticPlug10_2.wav', 'C_AcusticPlug10_3.wav', 'C_AcusticPlug10_4.wav', 'C_AcusticPlug11_1.wav', 'C_AcusticPlug11_2.wav', 'C_AcusticPlug11_3.wav', 'C_AcusticPlug11_4.wav', 'C_AcusticPlug12_1.wav', 'C_AcusticPlug12_2.wav', 'C_AcusticPlug12_3.wav', 'C_AcusticPlug12_4.wav', 'C_AcusticPlug13_1.wav', 'C_AcusticPlug13_2.wav', 'C_AcusticPlug13_3.wav', 'C_AcusticPlug13_4.wav', 'C_AcusticPlug14_1.wav', 'C_AcusticPlug14_2.wav', 'C_AcusticPlug14_3.wav', 'C_AcusticPlug14_4.wav', 'C_AcusticPlug15_1.wav', 'C_AcusticPlug15_2.wav', 'C_AcusticPlug15_3.wav', 'C_AcusticPlug15_4.wav', 'C_AcusticPlug16_1.wav', 'C_AcusticPlug16_2.wav', 'C_AcusticPlug16_3.wav', 'C_AcusticPlug16_4.wav', 'C_AcusticPlug17_1.wav', 'C_AcusticPlug17_2.wav', 'C_AcusticPlug17_3.wav', 'C_AcusticPlug17_4.wav', 'C_AcusticPlug18_1.wav', 'C_AcusticPlug18_2.wav', 'C_AcusticPlug18_3.wav', 'C_AcusticPlug18_4.wav', 'C_AcusticPlug19_1.wav', 'C_AcusticPlug19_2.wav', 'C_AcusticPlug19_3.wav', 'C_AcusticPlug19_4.wav', 'C_AcusticPlug1_1.wav', 'C_AcusticPlug1_2.wav', 'C_AcusticPlug1_3.wav', 'C_AcusticPlug1_4.wav', 'C_AcusticPlug20_1.wav', 'C_AcusticPlug20_2.wav', 'C_AcusticPlug20_3.wav', 'C_AcusticPlug20_4.wav', 'C_AcusticPlug21_1.wav', 'C_AcusticPlug21_2.wav', 'C_AcusticPlug21_3.wav', 'C_AcusticPlug21_4.wav', 'C_AcusticPlug22_1.wav', 'C_AcusticPlug22_2.wav', 'C_AcusticPlug22_3.wav', 'C_AcusticPlug22_4.wav', 'C_AcusticPlug23_1.wav', 'C_AcusticPlug23_2.wav', 'C_AcusticPlug23_3.wav', 'C_AcusticPlug23_4.wav', 'C_AcusticPlug24_1.wav', 'C_AcusticPlug24_2.wav', 'C_AcusticPlug24_3.wav', 'C_AcusticPlug24_4.wav', 'C_AcusticPlug25_1.wav', 'C_AcusticPlug25_2.wav', 'C_AcusticPlug25_3.wav', 'C_AcusticPlug25_4.wav', 'C_AcusticPlug26_1.wav', 'C_AcusticPlug26_2.wav', 'C_AcusticPlug26_3.wav', 'C_AcusticPlug26_4.wav', 'C_AcusticPlug27_1.wav', 'C_AcusticPlug27_2.wav', 'C_AcusticPlug27_3.wav', 'C_AcusticPlug27_4.wav', 'C_AcusticPlug28_1.wav', 'C_AcusticPlug28_2.wav', 'C_AcusticPlug28_3.wav', 'C_AcusticPlug28_4.wav', 'C_AcusticPlug29_1.wav', 'C_AcusticPlug29_2.wav', 'C_AcusticPlug29_3.wav', 'C_AcusticPlug29_4.wav', 'C_AcusticPlug2_1.wav', 'C_AcusticPlug2_2.wav', 'C_AcusticPlug2_3.wav', 'C_AcusticPlug2_4.wav', 'C_AcusticPlug30_1.wav', 'C_AcusticPlug30_2.wav', 'C_AcusticPlug30_3.wav', 'C_AcusticPlug30_4.wav', 'C_AcusticPlug3_1.wav', 'C_AcusticPlug3_2.wav', 'C_AcusticPlug3_3.wav', 'C_AcusticPlug3_4.wav', 'C_AcusticPlug4_1.wav', 'C_AcusticPlug4_2.wav', 'C_AcusticPlug4_3.wav', 'C_AcusticPlug4_4.wav', 'C_AcusticPlug5_1.wav', 'C_AcusticPlug5_2.wav', 'C_AcusticPlug5_3.wav', 'C_AcusticPlug5_4.wav', 'C_AcusticPlug6_1.wav', 'C_AcusticPlug6_2.wav', 'C_AcusticPlug6_3.wav', 'C_AcusticPlug6_4.wav', 'C_AcusticPlug7_1.wav', 'C_AcusticPlug7_2.wav', 'C_AcusticPlug7_3.wav', 'C_AcusticPlug7_4.wav', 'C_AcusticPlug8_1.wav', 'C_AcusticPlug8_2.wav', 'C_AcusticPlug8_3.wav', 'C_AcusticPlug8_4.wav', 'C_AcusticPlug9_1.wav', 'C_AcusticPlug9_2.wav', 'C_AcusticPlug9_3.wav', 'C_AcusticPlug9_4.wav', 'C_Acustic_Miguel_1.wav', 'C_Acustic_Miguel_2.wav', 'C_Acustic_Miguel_3.wav', 'C_Acustic_Miguel_4.wav', 'C_classical_henrique_1.wav', 'C_classical_henrique_2.wav', 'C_classical_henrique_3.wav', 'C_classical_henrique_4.wav', 'C_ClassicA_Miguel_1.wav', 'C_ClassicA_Miguel_2.wav', 'C_ClassicA_Miguel_3.wav', 'C_ClassicA_Miguel_4.wav', 'C_ClassicCleanGB_JO_1.wav', 'C_ClassicCleanGB_JO_2.wav', 'C_ClassicCleanGB_JO_3.wav', 'C_ClassicCleanGB_JO_4.wav', 'C_Classic_Jegundo_1.wav', 'C_Classic_Jegundo_2.wav', 'C_Classic_Jegundo_3.wav', 'C_Classic_Jegundo_4.wav', 'C_Classic_Miguel_1.wav', 'C_Classic_Miguel_2.wav', 'C_Classic_Miguel_3.wav', ' ...
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Dm
# ['Dm_acousticguitar_Mari_1.wav', 'Dm_acousticguitar_Mari_2.wav', 'Dm_acousticguitar_Mari_3.wav', 'Dm_acousticguitar_Mari_4.wav', 'Dm_acousticguitar_SalomCΓòá┬║Andrade_1.wav', 'Dm_acousticguitar_SalomCΓòá┬║Andrade_2.wav', 'Dm_acousticguitar_SalomCΓòá┬║Andrade_3.wav', 'Dm_acousticguitar_SalomCΓòá┬║Andrade_4.wav', 'Dm_acusticGB_JO_1.wav', 'Dm_acusticGB_JO_2.wav', 'Dm_acusticGB_JO_3.wav', 'Dm_acusticGB_JO_4.wav', 'Dm_AcusticPlug10_1.wav', 'Dm_AcusticPlug10_2.wav', 'Dm_AcusticPlug10_3.wav', 'Dm_AcusticPlug10_4.wav', 'Dm_AcusticPlug11_1.wav', 'Dm_AcusticPlug11_2.wav', 'Dm_AcusticPlug11_3.wav', 'Dm_AcusticPlug11_4.wav', 'Dm_AcusticPlug12_1.wav', 'Dm_AcusticPlug12_2.wav', 'Dm_AcusticPlug12_3.wav', 'Dm_AcusticPlug12_4.wav', 'Dm_AcusticPlug13_1.wav', 'Dm_AcusticPlug13_2.wav', 'Dm_AcusticPlug13_3.wav', 'Dm_AcusticPlug13_4.wav', 'Dm_AcusticPlug14_1.wav', 'Dm_AcusticPlug14_2.wav', 'Dm_AcusticPlug14_3.wav', 'Dm_AcusticPlug14_4.wav', 'Dm_AcusticPlug15_1.wav', 'Dm_AcusticPlug15_2.wav', 'Dm_AcusticPlug15_3.wav', 'Dm_AcusticPlug15_4.wav', 'Dm_AcusticPlug16_1.wav', 'Dm_AcusticPlug16_2.wav', 'Dm_AcusticPlug16_3.wav', 'Dm_AcusticPlug16_4.wav', 'Dm_AcusticPlug17_1.wav', 'Dm_AcusticPlug17_2.wav', 'Dm_AcusticPlug17_3.wav', 'Dm_AcusticPlug17_4.wav', 'Dm_AcusticPlug18_1.wav', 'Dm_AcusticPlug18_2.wav', 'Dm_AcusticPlug18_3.wav', 'Dm_AcusticPlug18_4.wav', 'Dm_AcusticPlug19_1.wav', 'Dm_AcusticPlug19_2.wav', 'Dm_AcusticPlug19_3.wav', 'Dm_AcusticPlug19_4.wav', 'Dm_AcusticPlug1_1.wav', 'Dm_AcusticPlug1_2.wav', 'Dm_AcusticPlug1_3.wav', 'Dm_AcusticPlug1_4.wav', 'Dm_AcusticPlug20_1.wav', 'Dm_AcusticPlug20_2.wav', 'Dm_AcusticPlug20_3.wav', 'Dm_AcusticPlug20_4.wav', 'Dm_AcusticPlug21_1.wav', 'Dm_AcusticPlug21_2.wav', 'Dm_AcusticPlug21_3.wav', 'Dm_AcusticPlug21_4.wav', 'Dm_AcusticPlug22_1.wav', 'Dm_AcusticPlug22_2.wav', 'Dm_AcusticPlug22_3.wav', 'Dm_AcusticPlug22_4.wav', 'Dm_AcusticPlug23_1.wav', 'Dm_AcusticPlug23_2.wav', 'Dm_AcusticPlug23_3.wav', 'Dm_AcusticPlug23_4.wav', 'Dm_AcusticPlug24_1.wav', 'Dm_AcusticPlug24_2.wav', 'Dm_AcusticPlug24_3.wav', 'Dm_AcusticPlug24_4.wav', 'Dm_AcusticPlug25_1.wav', 'Dm_AcusticPlug25_2.wav', 'Dm_AcusticPlug25_3.wav', 'Dm_AcusticPlug25_4.wav', 'Dm_AcusticPlug26_1.wav', 'Dm_AcusticPlug26_2.wav', 'Dm_AcusticPlug26_3.wav', 'Dm_AcusticPlug26_4.wav', 'Dm_AcusticPlug27_1.wav', 'Dm_AcusticPlug27_2.wav', 'Dm_AcusticPlug27_3.wav', 'Dm_AcusticPlug27_4.wav', 'Dm_AcusticPlug28_1.wav', 'Dm_AcusticPlug28_2.wav', 'Dm_AcusticPlug28_3.wav', 'Dm_AcusticPlug28_4.wav', 'Dm_AcusticPlug29 _1.wav', 'Dm_AcusticPlug29_2.wav', 'Dm_AcusticPlug29_3.wav', 'Dm_AcusticPlug29_4.wav', 'Dm_AcusticPlug2_1.wav', 'Dm_AcusticPlug2_2.wav', 'Dm_AcusticPlug2_3.wav', 'Dm_AcusticPlug2_4.wav', 'Dm_AcusticPlug30 _1.wav', 'Dm_AcusticPlug30_2.wav', 'Dm_AcusticPlug30_3.wav', 'Dm_AcusticPlug30_4.wav', 'Dm_AcusticPlug3_1.wav', 'Dm_AcusticPlug3_2.wav', 'Dm_AcusticPlug3_3.wav', 'Dm_AcusticPlug3_4.wav', 'Dm_AcusticPlug4_1.wav', 'Dm_AcusticPlug4_2.wav', 'Dm_AcusticPlug4_3.wav', 'Dm_AcusticPlug4_4.wav', 'Dm_AcusticPlug5_1.wav', 'Dm_AcusticPlug5_2.wav', 'Dm_AcusticPlug5_3.wav', 'Dm_AcusticPlug5_4.wav', 'Dm_AcusticPlug6_1.wav', 'Dm_AcusticPlug6_2.wav', 'Dm_AcusticPlug6_3.wav', 'Dm_AcusticPlug6_4.wav', 'Dm_AcusticPlug7_1.wav', 'Dm_AcusticPlug7_2.wav', 'Dm_AcusticPlug7_3.wav', 'Dm_AcusticPlug7_4.wav', 'Dm_AcusticPlug8_1.wav', 'Dm_AcusticPlug8_2.wav', 'Dm_AcusticPlug8_3.wav', 'Dm_AcusticPlug8_4.wav', 'Dm_AcusticPlug9_1.wav', 'Dm_AcusticPlug9_2.wav', 'Dm_AcusticPlug9_3.wav', 'Dm_AcusticPlug9_4.wav', 'Dm_Acustic_Miguel_1.wav', 'Dm_Acustic_Miguel_2.wav', 'Dm_Acustic_Miguel_3.wav', 'Dm_Acustic_Miguel_4.wav', 'Dm_classical_henrique_1.wav', 'Dm_classical_henrique_2.wav', 'Dm_classical_henrique_3.wav', 'Dm_classical_henrique_4.wav', 'Dm_ClassicA_Miguel_1.wav', 'Dm_ClassicA_Miguel_2.wav', 'Dm_ClassicA_Miguel_3.wav', 'Dm_ClassicA_Miguel_4.wav', 'Dm_ClassicCleanGB_1.wav', 'Dm_ClassicCleanGB_2.wav', 'Dm_ClassicCleanGB_3.wav', 'Dm_ClassicCleanGB_4.wav', 'Dm_Classic_Jegundo_1.wav', 'Dm_Classic_Jegundo_2 ...
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Em
# ['Em_acousticguitar_Mari_1.wav', 'Em_acousticguitar_Mari_2.wav', 'Em_acousticguitar_Mari_3.wav', 'Em_acousticguitar_Mari_4.wav', 'Em_acousticguitar_SalomCΓòá┬║Andrade_1.wav', 'Em_acousticguitar_SalomCΓòá┬║Andrade_2.wav', 'Em_acousticguitar_SalomCΓòá┬║Andrade_3.wav', 'Em_acousticguitar_SalomCΓòá┬║Andrade_4.wav', 'Em_acusticBG_JO_1.wav', 'Em_acusticBG_JO_2.wav', 'Em_acusticBG_JO_3.wav', 'Em_acusticBG_JO_4.wav', 'Em_AcusticPlug10_1.wav', 'Em_AcusticPlug10_2.wav', 'Em_AcusticPlug10_3.wav', 'Em_AcusticPlug10_4.wav', 'Em_AcusticPlug11_1.wav', 'Em_AcusticPlug11_2.wav', 'Em_AcusticPlug11_3.wav', 'Em_AcusticPlug11_4.wav', 'Em_AcusticPlug12_1.wav', 'Em_AcusticPlug12_2.wav', 'Em_AcusticPlug12_3.wav', 'Em_AcusticPlug12_4.wav', 'Em_AcusticPlug13_1.wav', 'Em_AcusticPlug13_2.wav', 'Em_AcusticPlug13_3.wav', 'Em_AcusticPlug13_4.wav', 'Em_AcusticPlug14_1.wav', 'Em_AcusticPlug14_2.wav', 'Em_AcusticPlug14_3.wav', 'Em_AcusticPlug14_4.wav', 'Em_AcusticPlug15_1.wav', 'Em_AcusticPlug15_2.wav', 'Em_AcusticPlug15_3.wav', 'Em_AcusticPlug15_4.wav', 'Em_AcusticPlug16_1.wav', 'Em_AcusticPlug16_2.wav', 'Em_AcusticPlug16_3.wav', 'Em_AcusticPlug16_4.wav', 'Em_AcusticPlug17_1.wav', 'Em_AcusticPlug17_2.wav', 'Em_AcusticPlug17_3.wav', 'Em_AcusticPlug17_4.wav', 'Em_AcusticPlug18_1.wav', 'Em_AcusticPlug18_2.wav', 'Em_AcusticPlug18_3.wav', 'Em_AcusticPlug18_4.wav', 'Em_AcusticPlug19_1.wav', 'Em_AcusticPlug19_2.wav', 'Em_AcusticPlug19_3.wav', 'Em_AcusticPlug19_4.wav', 'Em_AcusticPlug1_1.wav', 'Em_AcusticPlug1_2.wav', 'Em_AcusticPlug1_3.wav', 'Em_AcusticPlug1_4.wav', 'Em_AcusticPlug20_1.wav', 'Em_AcusticPlug20_2.wav', 'Em_AcusticPlug20_3.wav', 'Em_AcusticPlug20_4.wav', 'Em_AcusticPlug21_1.wav', 'Em_AcusticPlug21_2.wav', 'Em_AcusticPlug21_3.wav', 'Em_AcusticPlug21_4.wav', 'Em_AcusticPlug22_1.wav', 'Em_AcusticPlug22_2.wav', 'Em_AcusticPlug22_3.wav', 'Em_AcusticPlug22_4.wav', 'Em_AcusticPlug23_1.wav', 'Em_AcusticPlug23_2.wav', 'Em_AcusticPlug23_3.wav', 'Em_AcusticPlug23_4.wav', 'Em_AcusticPlug24_1.wav', 'Em_AcusticPlug24_2.wav', 'Em_AcusticPlug24_3.wav', 'Em_AcusticPlug24_4.wav', 'Em_AcusticPlug25_1.wav', 'Em_AcusticPlug25_2.wav', 'Em_AcusticPlug25_3.wav', 'Em_AcusticPlug25_4.wav', 'Em_AcusticPlug26_1.wav', 'Em_AcusticPlug26_2.wav', 'Em_AcusticPlug26_3.wav', 'Em_AcusticPlug26_4.wav', 'Em_AcusticPlug27_1.wav', 'Em_AcusticPlug27_2.wav', 'Em_AcusticPlug27_3.wav', 'Em_AcusticPlug27_4.wav', 'Em_AcusticPlug28_1.wav', 'Em_AcusticPlug28_2.wav', 'Em_AcusticPlug28_3.wav', 'Em_AcusticPlug28_4.wav', 'Em_AcusticPlug29_1.wav', 'Em_AcusticPlug29_2.wav', 'Em_AcusticPlug29_3.wav', 'Em_AcusticPlug29_4.wav', 'Em_AcusticPlug2_1.wav', 'Em_AcusticPlug2_2.wav', 'Em_AcusticPlug2_3.wav', 'Em_AcusticPlug2_4.wav', 'Em_AcusticPlug30_1.wav', 'Em_AcusticPlug30_2.wav', 'Em_AcusticPlug30_3.wav', 'Em_AcusticPlug30_4.wav', 'Em_AcusticPlug3_1.wav', 'Em_AcusticPlug3_2.wav', 'Em_AcusticPlug3_3.wav', 'Em_AcusticPlug3_4.wav', 'Em_AcusticPlug4_1.wav', 'Em_AcusticPlug4_2.wav', 'Em_AcusticPlug4_3.wav', 'Em_AcusticPlug4_4.wav', 'Em_AcusticPlug5_1.wav', 'Em_AcusticPlug5_2.wav', 'Em_AcusticPlug5_3.wav', 'Em_AcusticPlug5_4.wav', 'Em_AcusticPlug6_1.wav', 'Em_AcusticPlug6_2.wav', 'Em_AcusticPlug6_3.wav', 'Em_AcusticPlug6_4.wav', 'Em_AcusticPlug7_1.wav', 'Em_AcusticPlug7_2.wav', 'Em_AcusticPlug7_3.wav', 'Em_AcusticPlug7_4.wav', 'Em_AcusticPlug8_1.wav', 'Em_AcusticPlug8_2.wav', 'Em_AcusticPlug8_3.wav', 'Em_AcusticPlug8_4.wav', 'Em_AcusticPlug9_1.wav', 'Em_AcusticPlug9_2.wav', 'Em_AcusticPlug9_3.wav', 'Em_AcusticPlug9_4.wav', 'Em_Acustic_Miguel_1.wav', 'Em_Acustic_Miguel_2.wav', 'Em_Acustic_Miguel_3.wav', 'Em_Acustic_Miguel_4.wav', 'Em_classical_henrique_1.wav', 'Em_classical_henrique_2.wav', 'Em_classical_henrique_3.wav', 'Em_classical_henrique_4.wav', 'Em_ClassicA_Miguel_1.wav', 'Em_ClassicA_Miguel_2.wav', 'Em_ClassicA_Miguel_3.wav', 'Em_ClassicA_Miguel_4.wav', 'Em_ClassicCleanGB_1.wav', 'Em_ClassicCleanGB_2.wav', 'Em_ClassicCleanGB_3.wav', 'Em_ClassicCleanGB_4.wav', 'Em_Classic_Jegundo_1.wav', 'Em_Classic_Jegundo_2.w ...
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\F
# ['F_acousticguitar_Mari_1.wav', 'F_acousticguitar_Mari_2.wav', 'F_acousticguitar_Mari_3.wav', 'F_acousticguitar_Mari_4.wav', 'F_acousticguitar_SalomCΓòá┬║Andrade_1.wav', 'F_acousticguitar_SalomCΓòá┬║Andrade_2.wav', 'F_acousticguitar_SalomCΓòá┬║Andrade_3.wav', 'F_acousticguitar_SalomCΓòá┬║Andrade_4.wav', 'F_acusticGB_JO_1.wav', 'F_acusticGB_JO_2.wav', 'F_acusticGB_JO_3.wav', 'F_acusticGB_JO_4.wav', 'F_AcusticPlug10_1.wav', 'F_AcusticPlug10_2.wav', 'F_AcusticPlug10_3.wav', 'F_AcusticPlug10_4.wav', 'F_AcusticPlug11_1.wav', 'F_AcusticPlug11_2.wav', 'F_AcusticPlug11_3.wav', 'F_AcusticPlug11_4.wav', 'F_AcusticPlug12_1.wav', 'F_AcusticPlug12_2.wav', 'F_AcusticPlug12_3.wav', 'F_AcusticPlug12_4.wav', 'F_AcusticPlug13_1.wav', 'F_AcusticPlug13_2.wav', 'F_AcusticPlug13_3.wav', 'F_AcusticPlug13_4.wav', 'F_AcusticPlug14_1.wav', 'F_AcusticPlug14_2.wav', 'F_AcusticPlug14_3.wav', 'F_AcusticPlug14_4.wav', 'F_AcusticPlug15_1.wav', 'F_AcusticPlug15_2.wav', 'F_AcusticPlug15_3.wav', 'F_AcusticPlug15_4.wav', 'F_AcusticPlug16_1.wav', 'F_AcusticPlug16_2.wav', 'F_AcusticPlug16_3.wav', 'F_AcusticPlug16_4.wav', 'F_AcusticPlug17_1.wav', 'F_AcusticPlug17_2.wav', 'F_AcusticPlug17_3.wav', 'F_AcusticPlug17_4.wav', 'F_AcusticPlug18_1.wav', 'F_AcusticPlug18_2.wav', 'F_AcusticPlug18_3.wav', 'F_AcusticPlug18_4.wav', 'F_AcusticPlug19_1.wav', 'F_AcusticPlug19_2.wav', 'F_AcusticPlug19_3.wav', 'F_AcusticPlug19_4.wav', 'F_AcusticPlug1_1.wav', 'F_AcusticPlug1_2.wav', 'F_AcusticPlug1_3.wav', 'F_AcusticPlug1_4.wav', 'F_AcusticPlug20_1.wav', 'F_AcusticPlug20_2.wav', 'F_AcusticPlug20_3.wav', 'F_AcusticPlug20_4.wav', 'F_AcusticPlug21_1.wav', 'F_AcusticPlug21_2.wav', 'F_AcusticPlug21_3.wav', 'F_AcusticPlug21_4.wav', 'F_AcusticPlug22_1.wav', 'F_AcusticPlug22_2.wav', 'F_AcusticPlug22_3.wav', 'F_AcusticPlug22_4.wav', 'F_AcusticPlug23_1.wav', 'F_AcusticPlug23_2.wav', 'F_AcusticPlug23_3.wav', 'F_AcusticPlug23_4.wav', 'F_AcusticPlug24_1.wav', 'F_AcusticPlug24_2.wav', 'F_AcusticPlug24_3.wav', 'F_AcusticPlug24_4.wav', 'F_AcusticPlug25_1.wav', 'F_AcusticPlug25_2.wav', 'F_AcusticPlug25_3.wav', 'F_AcusticPlug25_4.wav', 'F_AcusticPlug26_1.wav', 'F_AcusticPlug26_2.wav', 'F_AcusticPlug26_3.wav', 'F_AcusticPlug26_4.wav', 'F_AcusticPlug27_1.wav', 'F_AcusticPlug27_2.wav', 'F_AcusticPlug27_3.wav', 'F_AcusticPlug27_4.wav', 'F_AcusticPlug28_1.wav', 'F_AcusticPlug28_2.wav', 'F_AcusticPlug28_3.wav', 'F_AcusticPlug28_4.wav', 'F_AcusticPlug29_1.wav', 'F_AcusticPlug29_2.wav', 'F_AcusticPlug29_3.wav', 'F_AcusticPlug29_4.wav', 'F_AcusticPlug2_1.wav', 'F_AcusticPlug2_2.wav', 'F_AcusticPlug2_3.wav', 'F_AcusticPlug2_4.wav', 'F_AcusticPlug30_1.wav', 'F_AcusticPlug30_2.wav', 'F_AcusticPlug30_3.wav', 'F_AcusticPlug30_4.wav', 'F_AcusticPlug3_1.wav', 'F_AcusticPlug3_2.wav', 'F_AcusticPlug3_3.wav', 'F_AcusticPlug3_4.wav', 'F_AcusticPlug4_1.wav', 'F_AcusticPlug4_2.wav', 'F_AcusticPlug4_3.wav', 'F_AcusticPlug4_4.wav', 'F_AcusticPlug5_1.wav', 'F_AcusticPlug5_2.wav', 'F_AcusticPlug5_3.wav', 'F_AcusticPlug5_4.wav', 'F_AcusticPlug6_1.wav', 'F_AcusticPlug6_2.wav', 'F_AcusticPlug6_3.wav', 'F_AcusticPlug6_4.wav', 'F_AcusticPlug7_1.wav', 'F_AcusticPlug7_2.wav', 'F_AcusticPlug7_3.wav', 'F_AcusticPlug7_4.wav', 'F_AcusticPlug8_1.wav', 'F_AcusticPlug8_2.wav', 'F_AcusticPlug8_3.wav', 'F_AcusticPlug8_4.wav', 'F_AcusticPlug9_1.wav', 'F_AcusticPlug9_2.wav', 'F_AcusticPlug9_3.wav', 'F_AcusticPlug9_4.wav', 'F_Acustic_Miguel_1.wav', 'F_Acustic_Miguel_2.wav', 'F_Acustic_Miguel_3.wav', 'F_Acustic_Miguel_4.wav', 'F_classical_henrique_1.wav', 'F_classical_henrique_2.wav', 'F_classical_henrique_3.wav', 'F_classical_henrique_4.wav', 'F_ClassicA_Miguel_1.wav', 'F_ClassicA_Miguel_2.wav', 'F_ClassicA_Miguel_3.wav', 'F_ClassicA_Miguel_4.wav', 'F_ClassicCleanGB_JO_1.wav', 'F_ClassicCleanGB_JO_2.wav', 'F_ClassicCleanGB_JO_3.wav', 'F_ClassicCleanGB_JO_4.wav', 'F_Classic_Jegundo_1.wav', 'F_Classic_Jegundo_2.wav', 'F_Classic_Jegundo_3.wav', 'F_Classic_Jegundo_4.wav', 'F_Classic_Miguel_1.wav', 'F_Classic_Miguel_2.wav', 'F_Classic_Miguel_3.wav', ' ...
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\G
# ['G_acousticguitar_Mari_1 17.51.39.wav', 'G_acousticguitar_Mari_2.wav', 'G_acousticguitar_Mari_3.wav', 'G_acousticguitar_Mari_4.wav', 'G_acousticguitar_SalomCΓòá┬║Andrade_1.wav', 'G_acousticguitar_SalomCΓòá┬║Andrade_2.wav', 'G_acousticguitar_SalomCΓòá┬║Andrade_3.wav', 'G_acousticguitar_SalomCΓòá┬║Andrade_4.wav', 'G_acusticGB_JO_1.wav', 'G_acusticGB_JO_2.wav', 'G_acusticGB_JO_3.wav', 'G_acusticGB_JO_4.wav', 'G_AcusticPlug10_1.wav', 'G_AcusticPlug10_2.wav', 'G_AcusticPlug10_3.wav', 'G_AcusticPlug10_4.wav', 'G_AcusticPlug11_1.wav', 'G_AcusticPlug11_2.wav', 'G_AcusticPlug11_3.wav', 'G_AcusticPlug11_4.wav', 'G_AcusticPlug12_1.wav', 'G_AcusticPlug12_2.wav', 'G_AcusticPlug12_3.wav', 'G_AcusticPlug12_4.wav', 'G_AcusticPlug13_1.wav', 'G_AcusticPlug13_2.wav', 'G_AcusticPlug13_3.wav', 'G_AcusticPlug13_4.wav', 'G_AcusticPlug14_1.wav', 'G_AcusticPlug14_2.wav', 'G_AcusticPlug14_3.wav', 'G_AcusticPlug14_4.wav', 'G_AcusticPlug15_1.wav', 'G_AcusticPlug15_2.wav', 'G_AcusticPlug15_3.wav', 'G_AcusticPlug15_4.wav', 'G_AcusticPlug16_1.wav', 'G_AcusticPlug16_2.wav', 'G_AcusticPlug16_3.wav', 'G_AcusticPlug16_4.wav', 'G_AcusticPlug17_1.wav', 'G_AcusticPlug17_2.wav', 'G_AcusticPlug17_3.wav', 'G_AcusticPlug17_4.wav', 'G_AcusticPlug18_1.wav', 'G_AcusticPlug18_2.wav', 'G_AcusticPlug18_3.wav', 'G_AcusticPlug18_4.wav', 'G_AcusticPlug19_1.wav', 'G_AcusticPlug19_2.wav', 'G_AcusticPlug19_3.wav', 'G_AcusticPlug19_4.wav', 'G_AcusticPlug1_1.wav', 'G_AcusticPlug1_2.wav', 'G_AcusticPlug1_3.wav', 'G_AcusticPlug1_4.wav', 'G_AcusticPlug20_1.wav', 'G_AcusticPlug20_2.wav', 'G_AcusticPlug20_3.wav', 'G_AcusticPlug20_4.wav', 'G_AcusticPlug21_1.wav', 'G_AcusticPlug21_2.wav', 'G_AcusticPlug21_3.wav', 'G_AcusticPlug21_4.wav', 'G_AcusticPlug22_1.wav', 'G_AcusticPlug22_2.wav', 'G_AcusticPlug22_3.wav', 'G_AcusticPlug22_4.wav', 'G_AcusticPlug23_1.wav', 'G_AcusticPlug23_2.wav', 'G_AcusticPlug23_3.wav', 'G_AcusticPlug23_4.wav', 'G_AcusticPlug24_1.wav', 'G_AcusticPlug24_2.wav', 'G_AcusticPlug24_3.wav', 'G_AcusticPlug24_4.wav', 'G_AcusticPlug25_1.wav', 'G_AcusticPlug25_2.wav', 'G_AcusticPlug25_3.wav', 'G_AcusticPlug25_4.wav', 'G_AcusticPlug26_1.wav', 'G_AcusticPlug26_2.wav', 'G_AcusticPlug26_3.wav', 'G_AcusticPlug26_4.wav', 'G_AcusticPlug27_1.wav', 'G_AcusticPlug27_2.wav', 'G_AcusticPlug27_3.wav', 'G_AcusticPlug27_4.wav', 'G_AcusticPlug28_1.wav', 'G_AcusticPlug28_2.wav', 'G_AcusticPlug28_3.wav', 'G_AcusticPlug28_4.wav', 'G_AcusticPlug29_1.wav', 'G_AcusticPlug29_2.wav', 'G_AcusticPlug29_3.wav', 'G_AcusticPlug29_4.wav', 'G_AcusticPlug2_1.wav', 'G_AcusticPlug2_2.wav', 'G_AcusticPlug2_3.wav', 'G_AcusticPlug2_4.wav', 'G_AcusticPlug30_1.wav', 'G_AcusticPlug30_2.wav', 'G_AcusticPlug30_3.wav', 'G_AcusticPlug30_4.wav', 'G_AcusticPlug3_1.wav', 'G_AcusticPlug3_2.wav', 'G_AcusticPlug3_3.wav', 'G_AcusticPlug3_4.wav', 'G_AcusticPlug4_1.wav', 'G_AcusticPlug4_2.wav', 'G_AcusticPlug4_3.wav', 'G_AcusticPlug4_4.wav', 'G_AcusticPlug5_1.wav', 'G_AcusticPlug5_2.wav', 'G_AcusticPlug5_3.wav', 'G_AcusticPlug5_4.wav', 'G_AcusticPlug6_1.wav', 'G_AcusticPlug6_2.wav', 'G_AcusticPlug6_3.wav', 'G_AcusticPlug6_4.wav', 'G_AcusticPlug7_1.wav', 'G_AcusticPlug7_2.wav', 'G_AcusticPlug7_3.wav', 'G_AcusticPlug7_4.wav', 'G_AcusticPlug8_1.wav', 'G_AcusticPlug8_2.wav', 'G_AcusticPlug8_3.wav', 'G_AcusticPlug8_4.wav', 'G_AcusticPlug9_1.wav', 'G_AcusticPlug9_2.wav', 'G_AcusticPlug9_3.wav', 'G_AcusticPlug9_4.wav', 'G_Acustic_Miguel_1.wav', 'G_Acustic_Miguel_2.wav', 'G_Acustic_Miguel_3.wav', 'G_Acustic_Miguel_4.wav', 'G_classical_henrique_1.wav', 'G_classical_henrique_2.wav', 'G_classical_henrique_3.wav', 'G_classical_henrique_4.wav', 'G_ClassicA_Miguel_1.wav', 'G_ClassicA_Miguel_2.wav', 'G_ClassicA_Miguel_3.wav', 'G_ClassicA_Miguel_4.wav', 'G_ClassicCleanGB_JO_1.wav', 'G_ClassicCleanGB_JO_2.wav', 'G_ClassicCleanGB_JO_3.wav', 'G_ClassicCleanGB_JO_4.wav', 'G_Classic_Jegundo_1.wav', 'G_Classic_Jegundo_2.wav', 'G_Classic_Jegundo_3.wav', 'G_Classic_Jegundo_4.wav', 'G_Classic_Miguel_1.wav', 'G_Classic_Miguel_2.wav', 'G_Classic_Miguel_ ...
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Am
# ['Am_AcousticGuitar_RodrigoMercador_1.wav', 'Am_AcousticGuitar_RodrigoMercador_2.wav', 'Am_AcousticGuitar_RodrigoMercador_3.wav', 'Am_AcousticGuitar_RodrigoMercador_4.wav', 'Am_AcusticVince_JO_1.wav', 'Am_AcusticVince_JO_2.wav', 'Am_AcusticVince_JO_3.wav', 'Am_AcusticVince_JO_4.wav', 'Am_Classic2_Carolina_1.wav', 'Am_Classic2_Carolina_2.wav', 'Am_Classic2_Carolina_3.wav', 'Am_Classic2_Carolina_4.wav', 'Am_Classic3_Carolina_1.wav', 'Am_Classic3_Carolina_2.wav', 'Am_Classic3_Carolina_3.wav', 'Am_Classic3_Carolina_4.wav', 'Am_classical_AfonsoLemos_-01.wav', 'Am_classical_AfonsoLemos_-02.wav', 'Am_classical_AfonsoLemos_-03.wav', 'Am_classical_AfonsoLemos_-04.wav', 'Am_ClassicVince_JO_1.wav', 'Am_ClassicVince_JO_2.wav', 'Am_ClassicVince_JO_3.wav', 'Am_ClassicVince_JO_4.wav', 'Am_Classic_Jo_1.wav', 'Am_Classic_Jo_2.wav', 'Am_Classic_Jo_3.wav', 'Am_Classic_Jo_4.wav', 'Am_Electric1_LInda_1.wav', 'Am_Electric1_LInda_2.wav', 'Am_Electric1_LInda_3.wav', 'Am_Electric1_LInda_4.wav', 'Am_Electric2_LInda_1.wav', 'Am_Electric2_LInda_2.wav', 'Am_Electric2_LInda_3.wav', 'Am_Electric2_LInda_4.wav', 'Am_electric_Isabel_1.wav', 'Am_electric_Isabel_2.wav', 'Am_electric_Isabel_3.wav', 'Am_electric_Isabel_4.wav']
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Bb
# ['Bb_AcousticGuitar_RodrigoMercador_1.wav', 'Bb_AcousticGuitar_RodrigoMercador_2.wav', 'Bb_AcousticGuitar_RodrigoMercador_3.wav', 'Bb_AcousticGuitar_RodrigoMercador_4.wav', 'Bb_AcusticVince_JO_1.wav', 'Bb_AcusticVince_JO_2.wav', 'Bb_AcusticVince_JO_3.wav', 'Bb_AcusticVince_JO_4.wav', 'Bb_Classic2_Carolina_1.wav', 'Bb_Classic2_Carolina_2.wav', 'Bb_Classic2_Carolina_3.wav', 'Bb_Classic2_Carolina_4.wav', 'Bb_Classic3_Carolina_1.wav', 'Bb_Classic3_Carolina_2.wav', 'Bb_Classic3_Carolina_3.wav', 'Bb_Classic3_Carolina_4.wav', 'Bb_classical_AfonsoLemos_-01.wav', 'Bb_classical_AfonsoLemos_-02.wav', 'Bb_classical_AfonsoLemos_-03.wav', 'Bb_classical_AfonsoLemos_-04.wav', 'Bb_ClassicVince_JO_1.wav', 'Bb_ClassicVince_JO_2.wav', 'Bb_ClassicVince_JO_3.wav', 'Bb_ClassicVince_JO_4.wav', 'Bb_Classic_Jo_1.wav', 'Bb_Classic_Jo_2.wav', 'Bb_Classic_Jo_3.wav', 'Bb_Classic_Jo_4.wav', 'Bb_Electric1_LInda_1.wav', 'Bb_Electric1_LInda_2.wav', 'Bb_Electric1_LInda_3.wav', 'Bb_Electric1_LInda_4.wav', 'Bb_Electric2_LInda_1.wav', 'Bb_Electric2_LInda_2.wav', 'Bb_Electric2_LInda_3.wav', 'Bb_Electric2_LInda_4.wav', 'Bb_electric_Isabel_1.wav', 'Bb_electric_Isabel_2.wav', 'Bb_electric_Isabel_3.wav', 'Bb_electric_Isabel_4.wav']
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Bdim
# ['Bdim_AcousticGuitar_RodrigoMercador_1.wav', 'Bdim_AcousticGuitar_RodrigoMercador_2.wav', 'Bdim_AcousticGuitar_RodrigoMercador_3.wav', 'Bdim_AcousticGuitar_RodrigoMercador_4.wav', 'Bdim_AcusticVince_JO_1.wav', 'Bdim_AcusticVince_JO_2.wav', 'Bdim_AcusticVince_JO_3.wav', 'Bdim_AcusticVince_JO_4.wav', 'Bdim_Classic2_Carolina_1.wav', 'Bdim_Classic2_Carolina_2.wav', 'Bdim_Classic2_Carolina_3.wav', 'Bdim_Classic2_Carolina_4.wav', 'Bdim_Classic3_Carolina_1.wav', 'Bdim_Classic3_Carolina_2.wav', 'Bdim_Classic3_Carolina_3.wav', 'Bdim_Classic3_Carolina_4.wav', 'Bdim_classical_AfonsoLemos_-01.wav', 'Bdim_classical_AfonsoLemos_-02.wav', 'Bdim_classical_AfonsoLemos_-03.wav', 'Bdim_classical_AfonsoLemos_-04.wav', 'Bdim_ClassicVince_JO_1.wav', 'Bdim_ClassicVince_JO_2.wav', 'Bdim_ClassicVince_JO_3.wav', 'Bdim_ClassicVince_JO_4.wav', 'Bdim_Classic_Jo_1.wav', 'Bdim_Classic_Jo_2.wav', 'Bdim_Classic_Jo_3.wav', 'Bdim_Classic_Jo_4.wav', 'Bdim_Electric1_LInda_1.wav', 'Bdim_Electric1_LInda_2.wav', 'Bdim_Electric1_LInda_3.wav', 'Bdim_Electric1_LInda_4.wav', 'Bdim_Electric2_LInda_1.wav', 'Bdim_Electric2_LInda_2.wav', 'Bdim_Electric2_LInda_3.wav', 'Bdim_Electric2_LInda_4.wav', 'Bdim_electric_Isabel_1.wav', 'Bdim_electric_Isabel_2.wav', 'Bdim_electric_Isabel_3.wav', 'Bdim_electric_Isabel_4.wav']
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\C
# ['C_AcousticGuitar_RodrigoMercador_1.wav', 'C_AcousticGuitar_RodrigoMercador_2.wav', 'C_AcousticGuitar_RodrigoMercador_3.wav', 'C_AcousticGuitar_RodrigoMercador_4.wav', 'C_AcusticVince_JO_1.wav', 'C_AcusticVince_JO_2.wav', 'C_AcusticVince_JO_3.wav', 'C_AcusticVince_JO_4.wav', 'C_Classic2_Carolina_1.wav', 'C_Classic2_Carolina_2.wav', 'C_Classic2_Carolina_3.wav', 'C_Classic2_Carolina_4.wav', 'C_Classic3_Carolina_1.wav', 'C_Classic3_Carolina_2.wav', 'C_Classic3_Carolina_3.wav', 'C_Classic3_Carolina_4.wav', 'C_classical_AfonsoLemos_-01.wav', 'C_classical_AfonsoLemos_-02.wav', 'C_classical_AfonsoLemos_-03.wav', 'C_classical_AfonsoLemos_-04.wav', 'C_ClassicVince_JO_1.wav', 'C_ClassicVince_JO_2.wav', 'C_ClassicVince_JO_3.wav', 'C_ClassicVince_JO_4.wav', 'C_Classic_Jo_1.wav', 'C_Classic_Jo_2.wav', 'C_Classic_Jo_3.wav', 'C_Classic_Jo_4.wav', 'C_Electric1_LInda_1.wav', 'C_Electric1_LInda_2.wav', 'C_Electric1_LInda_3.wav', 'C_Electric1_LInda_4.wav', 'C_Electric2_LInda_1.wav', 'C_Electric2_LInda_2.wav', 'C_Electric2_LInda_3.wav', 'C_Electric2_LInda_4.wav', 'C_electric_Isabel_1.wav', 'C_electric_Isabel_2.wav', 'C_electric_Isabel_3.wav', 'C_electric_Isabel_4.wav']
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Dm
# ['Dm_AcousticGuitar_RodrigoMercador_1.wav', 'Dm_AcousticGuitar_RodrigoMercador_2.wav', 'Dm_AcousticGuitar_RodrigoMercador_3.wav', 'Dm_AcousticGuitar_RodrigoMercador_4.wav', 'Dm_AcusticVince_JO_1.wav', 'Dm_AcusticVince_JO_2.wav', 'Dm_AcusticVince_JO_3.wav', 'Dm_AcusticVince_JO_4.wav', 'Dm_Classic2_Carolina_1.wav', 'Dm_Classic2_Carolina_2.wav', 'Dm_Classic2_Carolina_3.wav', 'Dm_Classic2_Carolina_4.wav', 'Dm_Classic3_Carolina_1.wav', 'Dm_Classic3_Carolina_2.wav', 'Dm_Classic3_Carolina_3.wav', 'Dm_Classic3_Carolina_4.wav', 'Dm_classical_AfonsoLemos_-01.wav', 'Dm_classical_AfonsoLemos_-02.wav', 'Dm_classical_AfonsoLemos_-03.wav', 'Dm_classical_AfonsoLemos_-04.wav', 'Dm_ClassicVince_JO_1.wav', 'Dm_ClassicVince_JO_2.wav', 'Dm_ClassicVince_JO_3.wav', 'Dm_ClassicVince_JO_4.wav', 'Dm_Classic_Jo_1.wav', 'Dm_Classic_Jo_2.wav', 'Dm_Classic_Jo_3.wav', 'Dm_Classic_Jo_4.wav', 'Dm_Electric1_LInda_1.wav', 'Dm_Electric1_LInda_2.wav', 'Dm_Electric1_LInda_3.wav', 'Dm_Electric1_LInda_4.wav', 'Dm_Electric2_LInda_1.wav', 'Dm_Electric2_LInda_2.wav', 'Dm_Electric2_LInda_3.wav', 'Dm_Electric2_LInda_4.wav', 'Dm_electric_Isabel_1.wav', 'Dm_electric_Isabel_2.wav', 'Dm_electric_Isabel_3.wav', 'Dm_electric_Isabel_4.wav']
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Em
# ['Em_AcousticGuitar_RodrigoMercador_1.wav', 'Em_AcousticGuitar_RodrigoMercador_2.wav', 'Em_AcousticGuitar_RodrigoMercador_3.wav', 'Em_AcousticGuitar_RodrigoMercador_4.wav', 'Em_AcusticVince_JO_1.wav', 'Em_AcusticVince_JO_2.wav', 'Em_AcusticVince_JO_3.wav', 'Em_AcusticVince_JO_4.wav', 'Em_Classic2_Carolina_1.wav', 'Em_Classic2_Carolina_2.wav', 'Em_Classic2_Carolina_3.wav', 'Em_Classic2_Carolina_4.wav', 'Em_Classic3_Carolina_1.wav', 'Em_Classic3_Carolina_2.wav', 'Em_Classic3_Carolina_3.wav', 'Em_Classic3_Carolina_4.wav', 'Em_classical_AfonsoLemos_01.wav', 'Em_classical_AfonsoLemos_02.wav', 'Em_classical_AfonsoLemos_03.wav', 'Em_classical_AfonsoLemos_04.wav', 'Em_ClassicVince_JO_1.wav', 'Em_ClassicVince_JO_2.wav', 'Em_ClassicVince_JO_3.wav', 'Em_ClassicVince_JO_4.wav', 'Em_Classic_Jo_1.wav', 'Em_Classic_Jo_2.wav', 'Em_Classic_Jo_3.wav', 'Em_Classic_Jo_4.wav', 'Em_Electric1_LInda_1.wav', 'Em_Electric1_LInda_2.wav', 'Em_Electric1_LInda_3.wav', 'Em_Electric1_LInda_4.wav', 'Em_Electric2_LInda_1..wav', 'Em_Electric2_LInda_2.wav', 'Em_Electric2_LInda_3.wav', 'Em_Electric2_LInda_4..wav', 'Em_electric_Isabel_1.wav', 'Em_electric_Isabel_2.wav', 'Em_electric_Isabel_3.wav', 'Em_electric_Isabel_4.wav']
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\F
# ['F_AcousticGuitar_RodrigoMercador_1.wav', 'F_AcousticGuitar_RodrigoMercador_2.wav', 'F_AcousticGuitar_RodrigoMercador_3.wav', 'F_AcousticGuitar_RodrigoMercador_4.wav', 'F_AcusticVince_JO_1.wav', 'F_AcusticVince_JO_2.wav', 'F_AcusticVince_JO_3.wav', 'F_AcusticVince_JO_4.wav', 'F_Classic2_Carolina_1.wav', 'F_Classic2_Carolina_2.wav', 'F_Classic2_Carolina_3.wav', 'F_Classic2_Carolina_4.wav', 'F_Classic3_Carolina_1.wav', 'F_Classic3_Carolina_2.wav', 'F_Classic3_Carolina_3.wav', 'F_Classic3_Carolina_4.wav', 'F_classical_AfonsoLemos_-01.wav', 'F_classical_AfonsoLemos_-02.wav', 'F_classical_AfonsoLemos_-03.wav', 'F_classical_AfonsoLemos_-04.wav', 'F_ClassicVince_JO_1.wav', 'F_ClassicVince_JO_2.wav', 'F_ClassicVince_JO_3.wav', 'F_ClassicVince_JO_4.wav', 'F_Classic_Jo_1..wav', 'F_Classic_Jo_2.wav', 'F_Classic_Jo_3.wav', 'F_Classic_Jo_4.wav', 'F_Electric1_LInda_1.wav', 'F_Electric1_LInda_2.wav', 'F_Electric1_LInda_3.wav', 'F_Electric1_LInda_4.wav', 'F_Electric2_LInda_1.wav', 'F_Electric2_LInda_2.wav', 'F_Electric2_LInda_3.wav', 'F_Electric2_LInda_4.wav', 'F_electric_Isabel_1.wav', 'F_electric_Isabel_2.wav', 'F_electric_Isabel_3.wav', 'F_electric_Isabel_4.wav']
#
#  C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\G
# ['G_AcousticGuitar_RodrigoMercador_1.wav', 'G_AcousticGuitar_RodrigoMercador_2.wav', 'G_AcousticGuitar_RodrigoMercador_3.wav', 'G_AcousticGuitar_RodrigoMercador_4.wav', 'G_AcusticVince_JO_1.wav', 'G_AcusticVince_JO_2.wav', 'G_AcusticVince_JO_3.wav', 'G_AcusticVince_JO_4.wav', 'G_Classic2_Carolina_1.wav', 'G_Classic2_Carolina_2.wav', 'G_Classic2_Carolina_3.wav', 'G_Classic2_Carolina_4.wav', 'G_Classic3_Carolina_1.wav', 'G_Classic3_Carolina_2.wav', 'G_Classic3_Carolina_3.wav', 'G_Classic3_Carolina_4.wav', 'G_classical_AfonsoLemos_-01.wav', 'G_classical_AfonsoLemos_-02.wav', 'G_classical_AfonsoLemos_-03.wav', 'G_classical_AfonsoLemos_-04.wav', 'G_ClassicVince_JO_1.wav', 'G_ClassicVince_JO_2.wav', 'G_ClassicVince_JO_3.wav', 'G_ClassicVince_JO_4.wav', 'G_Classic_Jo_1.wav', 'G_Classic_Jo_2.wav', 'G_Classic_Jo_3.wav', 'G_Classic_Jo_4.wav', 'G_Electric1_LInda_1.wav', 'G_Electric1_LInda_2.wav', 'G_Electric1_LInda_3.wav', 'G_Electric1_LInda_4.wav', 'G_Electric2_LInda_1.wav', 'G_Electric2_LInda_2.wav', 'G_Electric2_LInda_3.wav', 'G_Electric2_LInda_4.wav', 'G_electric_Isabel_1.wav', 'G_electric_Isabel_2.wav', 'G_electric_Isabel_3.wav', 'G_electric_Isabel_4.wav']

# %% [markdown]
# # Processing data for Model: Filenames

# %%
# Loops ever folder, loops each file in folder to rename
def clean_folder(folder_path):
    label_name = os.path.basename(folder_path)
    count = 1
    for fname in os.listdir(folder_path):
        ext = os.path.splitext(fname)[1].lower()
        old_path = os.path.join(folder_path, fname)
        if os.path.isfile(old_path):
            new_fname = f"{label_name}_{count:03d}{ext}"
            new_path = os.path.join(folder_path, new_fname)
            if old_path != new_path:
                try:
                    os.rename(old_path, new_path)
                    count += 1
                except Exception as e:
                    print('Failed to rename file', e)
                

######### Clean Training data ##########

#Loop all paths, clean file names in the paths
for path, files in train_result.items():
    clean_folder(path)
    
######### Clean Testing data ##########

#Loop all paths, clean file names in the paths
for path, files in test_result.items():
    clean_folder(path)

train_result = list_audios_with_path(train_dir, train_folder_names)
for path, files in train_result.items():
    print(f"\nCleaned: {path}")
    print(files)
        

test_result = list_audios_with_path(test_dir, test_folder_names)
for path, files in test_result.items():
    print(f"\nCleaned: {path}")
    print(files)
# Out:
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Am
# ['Am_001.wav', 'Am_002.wav', 'Am_003.wav', 'Am_004.wav', 'Am_005.wav', 'Am_006.wav', 'Am_007.wav', 'Am_008.wav', 'Am_009.wav', 'Am_010.wav', 'Am_011.wav', 'Am_012.wav', 'Am_013.wav', 'Am_014.wav', 'Am_015.wav', 'Am_016.wav', 'Am_017.wav', 'Am_018.wav', 'Am_019.wav', 'Am_020.wav', 'Am_021.wav', 'Am_022.wav', 'Am_023.wav', 'Am_024.wav', 'Am_025.wav', 'Am_026.wav', 'Am_027.wav', 'Am_028.wav', 'Am_029.wav', 'Am_030.wav', 'Am_031.wav', 'Am_032.wav', 'Am_033.wav', 'Am_034.wav', 'Am_035.wav', 'Am_036.wav', 'Am_037.wav', 'Am_038.wav', 'Am_039.wav', 'Am_040.wav', 'Am_041.wav', 'Am_042.wav', 'Am_043.wav', 'Am_044.wav', 'Am_045.wav', 'Am_046.wav', 'Am_047.wav', 'Am_048.wav', 'Am_049.wav', 'Am_050.wav', 'Am_051.wav', 'Am_052.wav', 'Am_053.wav', 'Am_054.wav', 'Am_055.wav', 'Am_056.wav', 'Am_057.wav', 'Am_058.wav', 'Am_059.wav', 'Am_060.wav', 'Am_061.wav', 'Am_062.wav', 'Am_063.wav', 'Am_064.wav', 'Am_065.wav', 'Am_066.wav', 'Am_067.wav', 'Am_068.wav', 'Am_069.wav', 'Am_070.wav', 'Am_071.wav', 'Am_072.wav', 'Am_073.wav', 'Am_074.wav', 'Am_075.wav', 'Am_076.wav', 'Am_077.wav', 'Am_078.wav', 'Am_079.wav', 'Am_080.wav', 'Am_081.wav', 'Am_082.wav', 'Am_083.wav', 'Am_084.wav', 'Am_085.wav', 'Am_086.wav', 'Am_087.wav', 'Am_088.wav', 'Am_089.wav', 'Am_090.wav', 'Am_091.wav', 'Am_092.wav', 'Am_093.wav', 'Am_094.wav', 'Am_095.wav', 'Am_096.wav', 'Am_097.wav', 'Am_098.wav', 'Am_099.wav', 'Am_100.wav', 'Am_101.wav', 'Am_102.wav', 'Am_103.wav', 'Am_104.wav', 'Am_105.wav', 'Am_106.wav', 'Am_107.wav', 'Am_108.wav', 'Am_109.wav', 'Am_110.wav', 'Am_111.wav', 'Am_112.wav', 'Am_113.wav', 'Am_114.wav', 'Am_115.wav', 'Am_116.wav', 'Am_117.wav', 'Am_118.wav', 'Am_119.wav', 'Am_120.wav', 'Am_121.wav', 'Am_122.wav', 'Am_123.wav', 'Am_124.wav', 'Am_125.wav', 'Am_126.wav', 'Am_127.wav', 'Am_128.wav', 'Am_129.wav', 'Am_130.wav', 'Am_131.wav', 'Am_132.wav', 'Am_133.wav', 'Am_134.wav', 'Am_135.wav', 'Am_136.wav', 'Am_137.wav', 'Am_138.wav', 'Am_139.wav', 'Am_140.wav', 'Am_141.wav', 'Am_142.wav', 'Am_143.wav', 'Am_144.wav', 'Am_145.wav', 'Am_146.wav', 'Am_147.wav', 'Am_148.wav', 'Am_149.wav', 'Am_150.wav', 'Am_151.wav', 'Am_152.wav', 'Am_153.wav', 'Am_154.wav', 'Am_155.wav', 'Am_156.wav', 'Am_157.wav', 'Am_158.wav', 'Am_159.wav', 'Am_160.wav', 'Am_161.wav', 'Am_162.wav', 'Am_163.wav', 'Am_164.wav', 'Am_165.wav', 'Am_166.wav', 'Am_167.wav', 'Am_168.wav', 'Am_169.wav', 'Am_170.wav', 'Am_171.wav', 'Am_172.wav', 'Am_173.wav', 'Am_174.wav', 'Am_175.wav', 'Am_176.wav', 'Am_177.wav', 'Am_178.wav', 'Am_179.wav', 'Am_180.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Bb
# ['Bb_001.wav', 'Bb_002.wav', 'Bb_003.wav', 'Bb_004.wav', 'Bb_005.wav', 'Bb_006.wav', 'Bb_007.wav', 'Bb_008.wav', 'Bb_009.wav', 'Bb_010.wav', 'Bb_011.wav', 'Bb_012.wav', 'Bb_013.wav', 'Bb_014.wav', 'Bb_015.wav', 'Bb_016.wav', 'Bb_017.wav', 'Bb_018.wav', 'Bb_019.wav', 'Bb_020.wav', 'Bb_021.wav', 'Bb_022.wav', 'Bb_023.wav', 'Bb_024.wav', 'Bb_025.wav', 'Bb_026.wav', 'Bb_027.wav', 'Bb_028.wav', 'Bb_029.wav', 'Bb_030.wav', 'Bb_031.wav', 'Bb_032.wav', 'Bb_033.wav', 'Bb_034.wav', 'Bb_035.wav', 'Bb_036.wav', 'Bb_037.wav', 'Bb_038.wav', 'Bb_039.wav', 'Bb_040.wav', 'Bb_041.wav', 'Bb_042.wav', 'Bb_043.wav', 'Bb_044.wav', 'Bb_045.wav', 'Bb_046.wav', 'Bb_047.wav', 'Bb_048.wav', 'Bb_049.wav', 'Bb_050.wav', 'Bb_051.wav', 'Bb_052.wav', 'Bb_053.wav', 'Bb_054.wav', 'Bb_055.wav', 'Bb_056.wav', 'Bb_057.wav', 'Bb_058.wav', 'Bb_059.wav', 'Bb_060.wav', 'Bb_061.wav', 'Bb_062.wav', 'Bb_063.wav', 'Bb_064.wav', 'Bb_065.wav', 'Bb_066.wav', 'Bb_067.wav', 'Bb_068.wav', 'Bb_069.wav', 'Bb_070.wav', 'Bb_071.wav', 'Bb_072.wav', 'Bb_073.wav', 'Bb_074.wav', 'Bb_075.wav', 'Bb_076.wav', 'Bb_077.wav', 'Bb_078.wav', 'Bb_079.wav', 'Bb_080.wav', 'Bb_081.wav', 'Bb_082.wav', 'Bb_083.wav', 'Bb_084.wav', 'Bb_085.wav', 'Bb_086.wav', 'Bb_087.wav', 'Bb_088.wav', 'Bb_089.wav', 'Bb_090.wav', 'Bb_091.wav', 'Bb_092.wav', 'Bb_093.wav', 'Bb_094.wav', 'Bb_095.wav', 'Bb_096.wav', 'Bb_097.wav', 'Bb_098.wav', 'Bb_099.wav', 'Bb_100.wav', 'Bb_101.wav', 'Bb_102.wav', 'Bb_103.wav', 'Bb_104.wav', 'Bb_105.wav', 'Bb_106.wav', 'Bb_107.wav', 'Bb_108.wav', 'Bb_109.wav', 'Bb_110.wav', 'Bb_111.wav', 'Bb_112.wav', 'Bb_113.wav', 'Bb_114.wav', 'Bb_115.wav', 'Bb_116.wav', 'Bb_117.wav', 'Bb_118.wav', 'Bb_119.wav', 'Bb_120.wav', 'Bb_121.wav', 'Bb_122.wav', 'Bb_123.wav', 'Bb_124.wav', 'Bb_125.wav', 'Bb_126.wav', 'Bb_127.wav', 'Bb_128.wav', 'Bb_129.wav', 'Bb_130.wav', 'Bb_131.wav', 'Bb_132.wav', 'Bb_133.wav', 'Bb_134.wav', 'Bb_135.wav', 'Bb_136.wav', 'Bb_137.wav', 'Bb_138.wav', 'Bb_139.wav', 'Bb_140.wav', 'Bb_141.wav', 'Bb_142.wav', 'Bb_143.wav', 'Bb_144.wav', 'Bb_145.wav', 'Bb_146.wav', 'Bb_147.wav', 'Bb_148.wav', 'Bb_149.wav', 'Bb_150.wav', 'Bb_151.wav', 'Bb_152.wav', 'Bb_153.wav', 'Bb_154.wav', 'Bb_155.wav', 'Bb_156.wav', 'Bb_157.wav', 'Bb_158.wav', 'Bb_159.wav', 'Bb_160.wav', 'Bb_161.wav', 'Bb_162.wav', 'Bb_163.wav', 'Bb_164.wav', 'Bb_165.wav', 'Bb_166.wav', 'Bb_167.wav', 'Bb_168.wav', 'Bb_169.wav', 'Bb_170.wav', 'Bb_171.wav', 'Bb_172.wav', 'Bb_173.wav', 'Bb_174.wav', 'Bb_175.wav', 'Bb_176.wav', 'Bb_177.wav', 'Bb_178.wav', 'Bb_179.wav', 'Bb_180.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Bdim
# ['Bdim_001.wav', 'Bdim_002.wav', 'Bdim_003.wav', 'Bdim_004.wav', 'Bdim_005.wav', 'Bdim_006.wav', 'Bdim_007.wav', 'Bdim_008.wav', 'Bdim_009.wav', 'Bdim_010.wav', 'Bdim_011.wav', 'Bdim_012.wav', 'Bdim_013.wav', 'Bdim_014.wav', 'Bdim_015.wav', 'Bdim_016.wav', 'Bdim_017.wav', 'Bdim_018.wav', 'Bdim_019.wav', 'Bdim_020.wav', 'Bdim_021.wav', 'Bdim_022.wav', 'Bdim_023.wav', 'Bdim_024.wav', 'Bdim_025.wav', 'Bdim_026.wav', 'Bdim_027.wav', 'Bdim_028.wav', 'Bdim_029.wav', 'Bdim_030.wav', 'Bdim_031.wav', 'Bdim_032.wav', 'Bdim_033.wav', 'Bdim_034.wav', 'Bdim_035.wav', 'Bdim_036.wav', 'Bdim_037.wav', 'Bdim_038.wav', 'Bdim_039.wav', 'Bdim_040.wav', 'Bdim_041.wav', 'Bdim_042.wav', 'Bdim_043.wav', 'Bdim_044.wav', 'Bdim_045.wav', 'Bdim_046.wav', 'Bdim_047.wav', 'Bdim_048.wav', 'Bdim_049.wav', 'Bdim_050.wav', 'Bdim_051.wav', 'Bdim_052.wav', 'Bdim_053.wav', 'Bdim_054.wav', 'Bdim_055.wav', 'Bdim_056.wav', 'Bdim_057.wav', 'Bdim_058.wav', 'Bdim_059.wav', 'Bdim_060.wav', 'Bdim_061.wav', 'Bdim_062.wav', 'Bdim_063.wav', 'Bdim_064.wav', 'Bdim_065.wav', 'Bdim_066.wav', 'Bdim_067.wav', 'Bdim_068.wav', 'Bdim_069.wav', 'Bdim_070.wav', 'Bdim_071.wav', 'Bdim_072.wav', 'Bdim_073.wav', 'Bdim_074.wav', 'Bdim_075.wav', 'Bdim_076.wav', 'Bdim_077.wav', 'Bdim_078.wav', 'Bdim_079.wav', 'Bdim_080.wav', 'Bdim_081.wav', 'Bdim_082.wav', 'Bdim_083.wav', 'Bdim_084.wav', 'Bdim_085.wav', 'Bdim_086.wav', 'Bdim_087.wav', 'Bdim_088.wav', 'Bdim_089.wav', 'Bdim_090.wav', 'Bdim_091.wav', 'Bdim_092.wav', 'Bdim_093.wav', 'Bdim_094.wav', 'Bdim_095.wav', 'Bdim_096.wav', 'Bdim_097.wav', 'Bdim_098.wav', 'Bdim_099.wav', 'Bdim_100.wav', 'Bdim_101.wav', 'Bdim_102.wav', 'Bdim_103.wav', 'Bdim_104.wav', 'Bdim_105.wav', 'Bdim_106.wav', 'Bdim_107.wav', 'Bdim_108.wav', 'Bdim_109.wav', 'Bdim_110.wav', 'Bdim_111.wav', 'Bdim_112.wav', 'Bdim_113.wav', 'Bdim_114.wav', 'Bdim_115.wav', 'Bdim_116.wav', 'Bdim_117.wav', 'Bdim_118.wav', 'Bdim_119.wav', 'Bdim_120.wav', 'Bdim_121.wav', 'Bdim_122.wav', 'Bdim_123.wav', 'Bdim_124.wav', 'Bdim_125.wav', 'Bdim_126.wav', 'Bdim_127.wav', 'Bdim_128.wav', 'Bdim_129.wav', 'Bdim_130.wav', 'Bdim_131.wav', 'Bdim_132.wav', 'Bdim_133.wav', 'Bdim_134.wav', 'Bdim_135.wav', 'Bdim_136.wav', 'Bdim_137.wav', 'Bdim_138.wav', 'Bdim_139.wav', 'Bdim_140.wav', 'Bdim_141.wav', 'Bdim_142.wav', 'Bdim_143.wav', 'Bdim_144.wav', 'Bdim_145.wav', 'Bdim_146.wav', 'Bdim_147.wav', 'Bdim_148.wav', 'Bdim_149.wav', 'Bdim_150.wav', 'Bdim_151.wav', 'Bdim_152.wav', 'Bdim_153.wav', 'Bdim_154.wav', 'Bdim_155.wav', 'Bdim_156.wav', 'Bdim_157.wav', 'Bdim_158.wav', 'Bdim_159.wav', 'Bdim_160.wav', 'Bdim_161.wav', 'Bdim_162.wav', 'Bdim_163.wav', 'Bdim_164.wav', 'Bdim_165.wav', 'Bdim_166.wav', 'Bdim_167.wav', 'Bdim_168.wav', 'Bdim_169.wav', 'Bdim_170.wav', 'Bdim_171.wav', 'Bdim_172.wav', 'Bdim_173.wav', 'Bdim_174.wav', 'Bdim_175.wav', 'Bdim_176.wav', 'Bdim_177.wav', 'Bdim_178.wav', 'Bdim_179.wav', 'Bdim_180.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\C
# ['C_001.wav', 'C_002.wav', 'C_003.wav', 'C_004.wav', 'C_005.wav', 'C_006.wav', 'C_007.wav', 'C_008.wav', 'C_009.wav', 'C_010.wav', 'C_011.wav', 'C_012.wav', 'C_013.wav', 'C_014.wav', 'C_015.wav', 'C_016.wav', 'C_017.wav', 'C_018.wav', 'C_019.wav', 'C_020.wav', 'C_021.wav', 'C_022.wav', 'C_023.wav', 'C_024.wav', 'C_025.wav', 'C_026.wav', 'C_027.wav', 'C_028.wav', 'C_029.wav', 'C_030.wav', 'C_031.wav', 'C_032.wav', 'C_033.wav', 'C_034.wav', 'C_035.wav', 'C_036.wav', 'C_037.wav', 'C_038.wav', 'C_039.wav', 'C_040.wav', 'C_041.wav', 'C_042.wav', 'C_043.wav', 'C_044.wav', 'C_045.wav', 'C_046.wav', 'C_047.wav', 'C_048.wav', 'C_049.wav', 'C_050.wav', 'C_051.wav', 'C_052.wav', 'C_053.wav', 'C_054.wav', 'C_055.wav', 'C_056.wav', 'C_057.wav', 'C_058.wav', 'C_059.wav', 'C_060.wav', 'C_061.wav', 'C_062.wav', 'C_063.wav', 'C_064.wav', 'C_065.wav', 'C_066.wav', 'C_067.wav', 'C_068.wav', 'C_069.wav', 'C_070.wav', 'C_071.wav', 'C_072.wav', 'C_073.wav', 'C_074.wav', 'C_075.wav', 'C_076.wav', 'C_077.wav', 'C_078.wav', 'C_079.wav', 'C_080.wav', 'C_081.wav', 'C_082.wav', 'C_083.wav', 'C_084.wav', 'C_085.wav', 'C_086.wav', 'C_087.wav', 'C_088.wav', 'C_089.wav', 'C_090.wav', 'C_091.wav', 'C_092.wav', 'C_093.wav', 'C_094.wav', 'C_095.wav', 'C_096.wav', 'C_097.wav', 'C_098.wav', 'C_099.wav', 'C_100.wav', 'C_101.wav', 'C_102.wav', 'C_103.wav', 'C_104.wav', 'C_105.wav', 'C_106.wav', 'C_107.wav', 'C_108.wav', 'C_109.wav', 'C_110.wav', 'C_111.wav', 'C_112.wav', 'C_113.wav', 'C_114.wav', 'C_115.wav', 'C_116.wav', 'C_117.wav', 'C_118.wav', 'C_119.wav', 'C_120.wav', 'C_121.wav', 'C_122.wav', 'C_123.wav', 'C_124.wav', 'C_125.wav', 'C_126.wav', 'C_127.wav', 'C_128.wav', 'C_129.wav', 'C_130.wav', 'C_131.wav', 'C_132.wav', 'C_133.wav', 'C_134.wav', 'C_135.wav', 'C_136.wav', 'C_137.wav', 'C_138.wav', 'C_139.wav', 'C_140.wav', 'C_141.wav', 'C_142.wav', 'C_143.wav', 'C_144.wav', 'C_145.wav', 'C_146.wav', 'C_147.wav', 'C_148.wav', 'C_149.wav', 'C_150.wav', 'C_151.wav', 'C_152.wav', 'C_153.wav', 'C_154.wav', 'C_155.wav', 'C_156.wav', 'C_157.wav', 'C_158.wav', 'C_159.wav', 'C_160.wav', 'C_161.wav', 'C_162.wav', 'C_163.wav', 'C_164.wav', 'C_165.wav', 'C_166.wav', 'C_167.wav', 'C_168.wav', 'C_169.wav', 'C_170.wav', 'C_171.wav', 'C_172.wav', 'C_173.wav', 'C_174.wav', 'C_175.wav', 'C_176.wav', 'C_177.wav', 'C_178.wav', 'C_179.wav', 'C_180.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Dm
# ['Dm_001.wav', 'Dm_002.wav', 'Dm_003.wav', 'Dm_004.wav', 'Dm_005.wav', 'Dm_006.wav', 'Dm_007.wav', 'Dm_008.wav', 'Dm_009.wav', 'Dm_010.wav', 'Dm_011.wav', 'Dm_012.wav', 'Dm_013.wav', 'Dm_014.wav', 'Dm_015.wav', 'Dm_016.wav', 'Dm_017.wav', 'Dm_018.wav', 'Dm_019.wav', 'Dm_020.wav', 'Dm_021.wav', 'Dm_022.wav', 'Dm_023.wav', 'Dm_024.wav', 'Dm_025.wav', 'Dm_026.wav', 'Dm_027.wav', 'Dm_028.wav', 'Dm_029.wav', 'Dm_030.wav', 'Dm_031.wav', 'Dm_032.wav', 'Dm_033.wav', 'Dm_034.wav', 'Dm_035.wav', 'Dm_036.wav', 'Dm_037.wav', 'Dm_038.wav', 'Dm_039.wav', 'Dm_040.wav', 'Dm_041.wav', 'Dm_042.wav', 'Dm_043.wav', 'Dm_044.wav', 'Dm_045.wav', 'Dm_046.wav', 'Dm_047.wav', 'Dm_048.wav', 'Dm_049.wav', 'Dm_050.wav', 'Dm_051.wav', 'Dm_052.wav', 'Dm_053.wav', 'Dm_054.wav', 'Dm_055.wav', 'Dm_056.wav', 'Dm_057.wav', 'Dm_058.wav', 'Dm_059.wav', 'Dm_060.wav', 'Dm_061.wav', 'Dm_062.wav', 'Dm_063.wav', 'Dm_064.wav', 'Dm_065.wav', 'Dm_066.wav', 'Dm_067.wav', 'Dm_068.wav', 'Dm_069.wav', 'Dm_070.wav', 'Dm_071.wav', 'Dm_072.wav', 'Dm_073.wav', 'Dm_074.wav', 'Dm_075.wav', 'Dm_076.wav', 'Dm_077.wav', 'Dm_078.wav', 'Dm_079.wav', 'Dm_080.wav', 'Dm_081.wav', 'Dm_082.wav', 'Dm_083.wav', 'Dm_084.wav', 'Dm_085.wav', 'Dm_086.wav', 'Dm_087.wav', 'Dm_088.wav', 'Dm_089.wav', 'Dm_090.wav', 'Dm_091.wav', 'Dm_092.wav', 'Dm_093.wav', 'Dm_094.wav', 'Dm_095.wav', 'Dm_096.wav', 'Dm_097.wav', 'Dm_098.wav', 'Dm_099.wav', 'Dm_100.wav', 'Dm_101.wav', 'Dm_102.wav', 'Dm_103.wav', 'Dm_104.wav', 'Dm_105.wav', 'Dm_106.wav', 'Dm_107.wav', 'Dm_108.wav', 'Dm_109.wav', 'Dm_110.wav', 'Dm_111.wav', 'Dm_112.wav', 'Dm_113.wav', 'Dm_114.wav', 'Dm_115.wav', 'Dm_116.wav', 'Dm_117.wav', 'Dm_118.wav', 'Dm_119.wav', 'Dm_120.wav', 'Dm_121.wav', 'Dm_122.wav', 'Dm_123.wav', 'Dm_124.wav', 'Dm_125.wav', 'Dm_126.wav', 'Dm_127.wav', 'Dm_128.wav', 'Dm_129.wav', 'Dm_130.wav', 'Dm_131.wav', 'Dm_132.wav', 'Dm_133.wav', 'Dm_134.wav', 'Dm_135.wav', 'Dm_136.wav', 'Dm_137.wav', 'Dm_138.wav', 'Dm_139.wav', 'Dm_140.wav', 'Dm_141.wav', 'Dm_142.wav', 'Dm_143.wav', 'Dm_144.wav', 'Dm_145.wav', 'Dm_146.wav', 'Dm_147.wav', 'Dm_148.wav', 'Dm_149.wav', 'Dm_150.wav', 'Dm_151.wav', 'Dm_152.wav', 'Dm_153.wav', 'Dm_154.wav', 'Dm_155.wav', 'Dm_156.wav', 'Dm_157.wav', 'Dm_158.wav', 'Dm_159.wav', 'Dm_160.wav', 'Dm_161.wav', 'Dm_162.wav', 'Dm_163.wav', 'Dm_164.wav', 'Dm_165.wav', 'Dm_166.wav', 'Dm_167.wav', 'Dm_168.wav', 'Dm_169.wav', 'Dm_170.wav', 'Dm_171.wav', 'Dm_172.wav', 'Dm_173.wav', 'Dm_174.wav', 'Dm_175.wav', 'Dm_176.wav', 'Dm_177.wav', 'Dm_178.wav', 'Dm_179.wav', 'Dm_180.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Em
# ['Em_001.wav', 'Em_002.wav', 'Em_003.wav', 'Em_004.wav', 'Em_005.wav', 'Em_006.wav', 'Em_007.wav', 'Em_008.wav', 'Em_009.wav', 'Em_010.wav', 'Em_011.wav', 'Em_012.wav', 'Em_013.wav', 'Em_014.wav', 'Em_015.wav', 'Em_016.wav', 'Em_017.wav', 'Em_018.wav', 'Em_019.wav', 'Em_020.wav', 'Em_021.wav', 'Em_022.wav', 'Em_023.wav', 'Em_024.wav', 'Em_025.wav', 'Em_026.wav', 'Em_027.wav', 'Em_028.wav', 'Em_029.wav', 'Em_030.wav', 'Em_031.wav', 'Em_032.wav', 'Em_033.wav', 'Em_034.wav', 'Em_035.wav', 'Em_036.wav', 'Em_037.wav', 'Em_038.wav', 'Em_039.wav', 'Em_040.wav', 'Em_041.wav', 'Em_042.wav', 'Em_043.wav', 'Em_044.wav', 'Em_045.wav', 'Em_046.wav', 'Em_047.wav', 'Em_048.wav', 'Em_049.wav', 'Em_050.wav', 'Em_051.wav', 'Em_052.wav', 'Em_053.wav', 'Em_054.wav', 'Em_055.wav', 'Em_056.wav', 'Em_057.wav', 'Em_058.wav', 'Em_059.wav', 'Em_060.wav', 'Em_061.wav', 'Em_062.wav', 'Em_063.wav', 'Em_064.wav', 'Em_065.wav', 'Em_066.wav', 'Em_067.wav', 'Em_068.wav', 'Em_069.wav', 'Em_070.wav', 'Em_071.wav', 'Em_072.wav', 'Em_073.wav', 'Em_074.wav', 'Em_075.wav', 'Em_076.wav', 'Em_077.wav', 'Em_078.wav', 'Em_079.wav', 'Em_080.wav', 'Em_081.wav', 'Em_082.wav', 'Em_083.wav', 'Em_084.wav', 'Em_085.wav', 'Em_086.wav', 'Em_087.wav', 'Em_088.wav', 'Em_089.wav', 'Em_090.wav', 'Em_091.wav', 'Em_092.wav', 'Em_093.wav', 'Em_094.wav', 'Em_095.wav', 'Em_096.wav', 'Em_097.wav', 'Em_098.wav', 'Em_099.wav', 'Em_100.wav', 'Em_101.wav', 'Em_102.wav', 'Em_103.wav', 'Em_104.wav', 'Em_105.wav', 'Em_106.wav', 'Em_107.wav', 'Em_108.wav', 'Em_109.wav', 'Em_110.wav', 'Em_111.wav', 'Em_112.wav', 'Em_113.wav', 'Em_114.wav', 'Em_115.wav', 'Em_116.wav', 'Em_117.wav', 'Em_118.wav', 'Em_119.wav', 'Em_120.wav', 'Em_121.wav', 'Em_122.wav', 'Em_123.wav', 'Em_124.wav', 'Em_125.wav', 'Em_126.wav', 'Em_127.wav', 'Em_128.wav', 'Em_129.wav', 'Em_130.wav', 'Em_131.wav', 'Em_132.wav', 'Em_133.wav', 'Em_134.wav', 'Em_135.wav', 'Em_136.wav', 'Em_137.wav', 'Em_138.wav', 'Em_139.wav', 'Em_140.wav', 'Em_141.wav', 'Em_142.wav', 'Em_143.wav', 'Em_144.wav', 'Em_145.wav', 'Em_146.wav', 'Em_147.wav', 'Em_148.wav', 'Em_149.wav', 'Em_150.wav', 'Em_151.wav', 'Em_152.wav', 'Em_153.wav', 'Em_154.wav', 'Em_155.wav', 'Em_156.wav', 'Em_157.wav', 'Em_158.wav', 'Em_159.wav', 'Em_160.wav', 'Em_161.wav', 'Em_162.wav', 'Em_163.wav', 'Em_164.wav', 'Em_165.wav', 'Em_166.wav', 'Em_167.wav', 'Em_168.wav', 'Em_169.wav', 'Em_170.wav', 'Em_171.wav', 'Em_172.wav', 'Em_173.wav', 'Em_174.wav', 'Em_175.wav', 'Em_176.wav', 'Em_177.wav', 'Em_178.wav', 'Em_179.wav', 'Em_180.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\F
# ['F_001.wav', 'F_002.wav', 'F_003.wav', 'F_004.wav', 'F_005.wav', 'F_006.wav', 'F_007.wav', 'F_008.wav', 'F_009.wav', 'F_010.wav', 'F_011.wav', 'F_012.wav', 'F_013.wav', 'F_014.wav', 'F_015.wav', 'F_016.wav', 'F_017.wav', 'F_018.wav', 'F_019.wav', 'F_020.wav', 'F_021.wav', 'F_022.wav', 'F_023.wav', 'F_024.wav', 'F_025.wav', 'F_026.wav', 'F_027.wav', 'F_028.wav', 'F_029.wav', 'F_030.wav', 'F_031.wav', 'F_032.wav', 'F_033.wav', 'F_034.wav', 'F_035.wav', 'F_036.wav', 'F_037.wav', 'F_038.wav', 'F_039.wav', 'F_040.wav', 'F_041.wav', 'F_042.wav', 'F_043.wav', 'F_044.wav', 'F_045.wav', 'F_046.wav', 'F_047.wav', 'F_048.wav', 'F_049.wav', 'F_050.wav', 'F_051.wav', 'F_052.wav', 'F_053.wav', 'F_054.wav', 'F_055.wav', 'F_056.wav', 'F_057.wav', 'F_058.wav', 'F_059.wav', 'F_060.wav', 'F_061.wav', 'F_062.wav', 'F_063.wav', 'F_064.wav', 'F_065.wav', 'F_066.wav', 'F_067.wav', 'F_068.wav', 'F_069.wav', 'F_070.wav', 'F_071.wav', 'F_072.wav', 'F_073.wav', 'F_074.wav', 'F_075.wav', 'F_076.wav', 'F_077.wav', 'F_078.wav', 'F_079.wav', 'F_080.wav', 'F_081.wav', 'F_082.wav', 'F_083.wav', 'F_084.wav', 'F_085.wav', 'F_086.wav', 'F_087.wav', 'F_088.wav', 'F_089.wav', 'F_090.wav', 'F_091.wav', 'F_092.wav', 'F_093.wav', 'F_094.wav', 'F_095.wav', 'F_096.wav', 'F_097.wav', 'F_098.wav', 'F_099.wav', 'F_100.wav', 'F_101.wav', 'F_102.wav', 'F_103.wav', 'F_104.wav', 'F_105.wav', 'F_106.wav', 'F_107.wav', 'F_108.wav', 'F_109.wav', 'F_110.wav', 'F_111.wav', 'F_112.wav', 'F_113.wav', 'F_114.wav', 'F_115.wav', 'F_116.wav', 'F_117.wav', 'F_118.wav', 'F_119.wav', 'F_120.wav', 'F_121.wav', 'F_122.wav', 'F_123.wav', 'F_124.wav', 'F_125.wav', 'F_126.wav', 'F_127.wav', 'F_128.wav', 'F_129.wav', 'F_130.wav', 'F_131.wav', 'F_132.wav', 'F_133.wav', 'F_134.wav', 'F_135.wav', 'F_136.wav', 'F_137.wav', 'F_138.wav', 'F_139.wav', 'F_140.wav', 'F_141.wav', 'F_142.wav', 'F_143.wav', 'F_144.wav', 'F_145.wav', 'F_146.wav', 'F_147.wav', 'F_148.wav', 'F_149.wav', 'F_150.wav', 'F_151.wav', 'F_152.wav', 'F_153.wav', 'F_154.wav', 'F_155.wav', 'F_156.wav', 'F_157.wav', 'F_158.wav', 'F_159.wav', 'F_160.wav', 'F_161.wav', 'F_162.wav', 'F_163.wav', 'F_164.wav', 'F_165.wav', 'F_166.wav', 'F_167.wav', 'F_168.wav', 'F_169.wav', 'F_170.wav', 'F_171.wav', 'F_172.wav', 'F_173.wav', 'F_174.wav', 'F_175.wav', 'F_176.wav', 'F_177.wav', 'F_178.wav', 'F_179.wav', 'F_180.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\G
# ['G_001.wav', 'G_002.wav', 'G_003.wav', 'G_004.wav', 'G_005.wav', 'G_006.wav', 'G_007.wav', 'G_008.wav', 'G_009.wav', 'G_010.wav', 'G_011.wav', 'G_012.wav', 'G_013.wav', 'G_014.wav', 'G_015.wav', 'G_016.wav', 'G_017.wav', 'G_018.wav', 'G_019.wav', 'G_020.wav', 'G_021.wav', 'G_022.wav', 'G_023.wav', 'G_024.wav', 'G_025.wav', 'G_026.wav', 'G_027.wav', 'G_028.wav', 'G_029.wav', 'G_030.wav', 'G_031.wav', 'G_032.wav', 'G_033.wav', 'G_034.wav', 'G_035.wav', 'G_036.wav', 'G_037.wav', 'G_038.wav', 'G_039.wav', 'G_040.wav', 'G_041.wav', 'G_042.wav', 'G_043.wav', 'G_044.wav', 'G_045.wav', 'G_046.wav', 'G_047.wav', 'G_048.wav', 'G_049.wav', 'G_050.wav', 'G_051.wav', 'G_052.wav', 'G_053.wav', 'G_054.wav', 'G_055.wav', 'G_056.wav', 'G_057.wav', 'G_058.wav', 'G_059.wav', 'G_060.wav', 'G_061.wav', 'G_062.wav', 'G_063.wav', 'G_064.wav', 'G_065.wav', 'G_066.wav', 'G_067.wav', 'G_068.wav', 'G_069.wav', 'G_070.wav', 'G_071.wav', 'G_072.wav', 'G_073.wav', 'G_074.wav', 'G_075.wav', 'G_076.wav', 'G_077.wav', 'G_078.wav', 'G_079.wav', 'G_080.wav', 'G_081.wav', 'G_082.wav', 'G_083.wav', 'G_084.wav', 'G_085.wav', 'G_086.wav', 'G_087.wav', 'G_088.wav', 'G_089.wav', 'G_090.wav', 'G_091.wav', 'G_092.wav', 'G_093.wav', 'G_094.wav', 'G_095.wav', 'G_096.wav', 'G_097.wav', 'G_098.wav', 'G_099.wav', 'G_100.wav', 'G_101.wav', 'G_102.wav', 'G_103.wav', 'G_104.wav', 'G_105.wav', 'G_106.wav', 'G_107.wav', 'G_108.wav', 'G_109.wav', 'G_110.wav', 'G_111.wav', 'G_112.wav', 'G_113.wav', 'G_114.wav', 'G_115.wav', 'G_116.wav', 'G_117.wav', 'G_118.wav', 'G_119.wav', 'G_120.wav', 'G_121.wav', 'G_122.wav', 'G_123.wav', 'G_124.wav', 'G_125.wav', 'G_126.wav', 'G_127.wav', 'G_128.wav', 'G_129.wav', 'G_130.wav', 'G_131.wav', 'G_132.wav', 'G_133.wav', 'G_134.wav', 'G_135.wav', 'G_136.wav', 'G_137.wav', 'G_138.wav', 'G_139.wav', 'G_140.wav', 'G_141.wav', 'G_142.wav', 'G_143.wav', 'G_144.wav', 'G_145.wav', 'G_146.wav', 'G_147.wav', 'G_148.wav', 'G_149.wav', 'G_150.wav', 'G_151.wav', 'G_152.wav', 'G_153.wav', 'G_154.wav', 'G_155.wav', 'G_156.wav', 'G_157.wav', 'G_158.wav', 'G_159.wav', 'G_160.wav', 'G_161.wav', 'G_162.wav', 'G_163.wav', 'G_164.wav', 'G_165.wav', 'G_166.wav', 'G_167.wav', 'G_168.wav', 'G_169.wav', 'G_170.wav', 'G_171.wav', 'G_172.wav', 'G_173.wav', 'G_174.wav', 'G_175.wav', 'G_176.wav', 'G_177.wav', 'G_178.wav', 'G_179.wav', 'G_180.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Am
# ['Am_001.wav', 'Am_002.wav', 'Am_003.wav', 'Am_004.wav', 'Am_005.wav', 'Am_006.wav', 'Am_007.wav', 'Am_008.wav', 'Am_009.wav', 'Am_010.wav', 'Am_011.wav', 'Am_012.wav', 'Am_013.wav', 'Am_014.wav', 'Am_015.wav', 'Am_016.wav', 'Am_017.wav', 'Am_018.wav', 'Am_019.wav', 'Am_020.wav', 'Am_021.wav', 'Am_022.wav', 'Am_023.wav', 'Am_024.wav', 'Am_025.wav', 'Am_026.wav', 'Am_027.wav', 'Am_028.wav', 'Am_029.wav', 'Am_030.wav', 'Am_031.wav', 'Am_032.wav', 'Am_033.wav', 'Am_034.wav', 'Am_035.wav', 'Am_036.wav', 'Am_037.wav', 'Am_038.wav', 'Am_039.wav', 'Am_040.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Bb
# ['Bb_001.wav', 'Bb_002.wav', 'Bb_003.wav', 'Bb_004.wav', 'Bb_005.wav', 'Bb_006.wav', 'Bb_007.wav', 'Bb_008.wav', 'Bb_009.wav', 'Bb_010.wav', 'Bb_011.wav', 'Bb_012.wav', 'Bb_013.wav', 'Bb_014.wav', 'Bb_015.wav', 'Bb_016.wav', 'Bb_017.wav', 'Bb_018.wav', 'Bb_019.wav', 'Bb_020.wav', 'Bb_021.wav', 'Bb_022.wav', 'Bb_023.wav', 'Bb_024.wav', 'Bb_025.wav', 'Bb_026.wav', 'Bb_027.wav', 'Bb_028.wav', 'Bb_029.wav', 'Bb_030.wav', 'Bb_031.wav', 'Bb_032.wav', 'Bb_033.wav', 'Bb_034.wav', 'Bb_035.wav', 'Bb_036.wav', 'Bb_037.wav', 'Bb_038.wav', 'Bb_039.wav', 'Bb_040.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Bdim
# ['Bdim_001.wav', 'Bdim_002.wav', 'Bdim_003.wav', 'Bdim_004.wav', 'Bdim_005.wav', 'Bdim_006.wav', 'Bdim_007.wav', 'Bdim_008.wav', 'Bdim_009.wav', 'Bdim_010.wav', 'Bdim_011.wav', 'Bdim_012.wav', 'Bdim_013.wav', 'Bdim_014.wav', 'Bdim_015.wav', 'Bdim_016.wav', 'Bdim_017.wav', 'Bdim_018.wav', 'Bdim_019.wav', 'Bdim_020.wav', 'Bdim_021.wav', 'Bdim_022.wav', 'Bdim_023.wav', 'Bdim_024.wav', 'Bdim_025.wav', 'Bdim_026.wav', 'Bdim_027.wav', 'Bdim_028.wav', 'Bdim_029.wav', 'Bdim_030.wav', 'Bdim_031.wav', 'Bdim_032.wav', 'Bdim_033.wav', 'Bdim_034.wav', 'Bdim_035.wav', 'Bdim_036.wav', 'Bdim_037.wav', 'Bdim_038.wav', 'Bdim_039.wav', 'Bdim_040.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\C
# ['C_001.wav', 'C_002.wav', 'C_003.wav', 'C_004.wav', 'C_005.wav', 'C_006.wav', 'C_007.wav', 'C_008.wav', 'C_009.wav', 'C_010.wav', 'C_011.wav', 'C_012.wav', 'C_013.wav', 'C_014.wav', 'C_015.wav', 'C_016.wav', 'C_017.wav', 'C_018.wav', 'C_019.wav', 'C_020.wav', 'C_021.wav', 'C_022.wav', 'C_023.wav', 'C_024.wav', 'C_025.wav', 'C_026.wav', 'C_027.wav', 'C_028.wav', 'C_029.wav', 'C_030.wav', 'C_031.wav', 'C_032.wav', 'C_033.wav', 'C_034.wav', 'C_035.wav', 'C_036.wav', 'C_037.wav', 'C_038.wav', 'C_039.wav', 'C_040.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Dm
# ['Dm_001.wav', 'Dm_002.wav', 'Dm_003.wav', 'Dm_004.wav', 'Dm_005.wav', 'Dm_006.wav', 'Dm_007.wav', 'Dm_008.wav', 'Dm_009.wav', 'Dm_010.wav', 'Dm_011.wav', 'Dm_012.wav', 'Dm_013.wav', 'Dm_014.wav', 'Dm_015.wav', 'Dm_016.wav', 'Dm_017.wav', 'Dm_018.wav', 'Dm_019.wav', 'Dm_020.wav', 'Dm_021.wav', 'Dm_022.wav', 'Dm_023.wav', 'Dm_024.wav', 'Dm_025.wav', 'Dm_026.wav', 'Dm_027.wav', 'Dm_028.wav', 'Dm_029.wav', 'Dm_030.wav', 'Dm_031.wav', 'Dm_032.wav', 'Dm_033.wav', 'Dm_034.wav', 'Dm_035.wav', 'Dm_036.wav', 'Dm_037.wav', 'Dm_038.wav', 'Dm_039.wav', 'Dm_040.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Em
# ['Em_001.wav', 'Em_002.wav', 'Em_003.wav', 'Em_004.wav', 'Em_005.wav', 'Em_006.wav', 'Em_007.wav', 'Em_008.wav', 'Em_009.wav', 'Em_010.wav', 'Em_011.wav', 'Em_012.wav', 'Em_013.wav', 'Em_014.wav', 'Em_015.wav', 'Em_016.wav', 'Em_017.wav', 'Em_018.wav', 'Em_019.wav', 'Em_020.wav', 'Em_021.wav', 'Em_022.wav', 'Em_023.wav', 'Em_024.wav', 'Em_025.wav', 'Em_026.wav', 'Em_027.wav', 'Em_028.wav', 'Em_029.wav', 'Em_030.wav', 'Em_031.wav', 'Em_032.wav', 'Em_033.wav', 'Em_034.wav', 'Em_035.wav', 'Em_036.wav', 'Em_037.wav', 'Em_038.wav', 'Em_039.wav', 'Em_040.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\F
# ['F_001.wav', 'F_002.wav', 'F_003.wav', 'F_004.wav', 'F_005.wav', 'F_006.wav', 'F_007.wav', 'F_008.wav', 'F_009.wav', 'F_010.wav', 'F_011.wav', 'F_012.wav', 'F_013.wav', 'F_014.wav', 'F_015.wav', 'F_016.wav', 'F_017.wav', 'F_018.wav', 'F_019.wav', 'F_020.wav', 'F_021.wav', 'F_022.wav', 'F_023.wav', 'F_024.wav', 'F_025.wav', 'F_026.wav', 'F_027.wav', 'F_028.wav', 'F_029.wav', 'F_030.wav', 'F_031.wav', 'F_032.wav', 'F_033.wav', 'F_034.wav', 'F_035.wav', 'F_036.wav', 'F_037.wav', 'F_038.wav', 'F_039.wav', 'F_040.wav']
#
# Cleaned: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\G
# ['G_001.wav', 'G_002.wav', 'G_003.wav', 'G_004.wav', 'G_005.wav', 'G_006.wav', 'G_007.wav', 'G_008.wav', 'G_009.wav', 'G_010.wav', 'G_011.wav', 'G_012.wav', 'G_013.wav', 'G_014.wav', 'G_015.wav', 'G_016.wav', 'G_017.wav', 'G_018.wav', 'G_019.wav', 'G_020.wav', 'G_021.wav', 'G_022.wav', 'G_023.wav', 'G_024.wav', 'G_025.wav', 'G_026.wav', 'G_027.wav', 'G_028.wav', 'G_029.wav', 'G_030.wav', 'G_031.wav', 'G_032.wav', 'G_033.wav', 'G_034.wav', 'G_035.wav', 'G_036.wav', 'G_037.wav', 'G_038.wav', 'G_039.wav', 'G_040.wav']

# %%
total_train_Count = 0
total_test_Count = 0

#Create array of chord paths in the training data folder.
training_folder_paths = [os.path.join(train_dir, folderName) for folderName in train_folder_names if os.path.isdir(os.path.join(train_dir, folderName))]

for path in training_folder_paths:
    count = 0
    for root, dirs, files in os.walk(path):
        for name in files:
            count += 1
    print(path, " total: ", count)
    total_train_Count += count
print( "\n", "Training files total: ", total_train_Count, "\n")

#Create array of chord paths in the testing data folder.
testing_folder_paths = [os.path.join(test_dir, folderName) for folderName in test_folder_names if os.path.isdir(os.path.join(test_dir, folderName))]

for path in testing_folder_paths:
    count = 0
    for root, dirs, files in os.walk(path):
        for name in files:
            count += 1
    print(path, " total: ", count)
    total_test_Count += count
print( "\n", "Testing files total: ", total_test_Count)
# Out:
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Am  total:  180
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Bb  total:  180
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Bdim  total:  180
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\C  total:  180
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Dm  total:  180
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Em  total:  180
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\F  total:  180
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\G  total:  180
#
#  Training files total:  1440
#
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Am  total:  40
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Bb  total:  40
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Bdim  total:  40
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\C  total:  40
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Dm  total:  40
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Em  total:  40
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\F  total:  40
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\G  total:  40
#
#  Testing files total:  320

# %%
label_to_index = {str(label): i for i, label in enumerate(train_folder_names)}
index_to_label = {i: str(label) for label, i in label_to_index.items()}

print("Full paths for training file: " + "\n")
training_samples = []
for root, dirs, files in os.walk(train_dir):
    for name in files:
        full_path = os.path.join(root, name)
        training_samples.append(full_path)

print(training_samples[0], "\n")


print("full paths for testing file: " + "\n")
testing_samples = []
for root, dirs, files in os.walk(test_dir):
    for name in files:
        full_path = os.path.join(root, name)
        testing_samples.append(full_path)

print(testing_samples[5])
# Out:
# Full paths for training file:
#
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Am\Am_001.wav
#
# full paths for testing file:
#
# C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Am\Am_006.wav

# %% [markdown]
# # Create uniform audio files 64kHz (2 seconds)

# %%
# Array of chord paths in the training data folder: training_folder_paths
# Array of chord paths in the testing data folder: testing_folder_paths


#Set length of all audios, to 64000khz, 16000 sample rate. Duration is 4 seconds
def create_waveforms(folder_path, target_sr=16000, target_len=64000):
    
    audios = []
    labels = []
    file_names = []
    paths = []
    original_len = []
    
    # base path for each folder is the label for each classification
    label = str(os.path.basename(folder_path))
    # Gets index numbers based on folder label
    label_index = label_to_index.get(label)
    
    # Librosa - Convert audio file to waveform
    for file in os.listdir(folder_path):
        if file.endswith(".wav"):
            file_path = os.path.join(folder_path, file)
            y, sr = librosa.load(file_path, sr=target_sr, mono=True)
            original_len.append(y.shape)
            # trim audio frames with no noise, less than 20 decibels
            y_trimmed, _ = librosa.effects.trim(y, top_db=20)
            # scale waveforms to standard range
            y_trimmed = y_trimmed / np.max(np.abs(y_trimmed))
            # Set length to 64000
            y_fixed = librosa.util.fix_length(y_trimmed, size=target_len)
            audios.append(y_fixed)
            labels.append(label_index)
            paths.append(file_path)
            file_names.append(file)

    if audios:
        print(f"Label: {labels[0]}, Original Shape: {original_len[0]} Fixed Shape: {audios[0].shape}, Total fixed: {len(audios)}")
            
    #Each .wav now labelled by number below
    return audios, labels, sr, file_names, paths

print("shaping all audios to length 64000")


audios = []
labels = []
file_names = []
paths = []

# For every  training folder path, load_and_set_wav_files()
for path in training_folder_paths:
    audios_batch, labels_batch, sr, file_names_batch, paths_batch = create_waveforms(path)
    audios.extend(audios_batch)
    labels.extend(labels_batch)
    file_names.extend(file_names_batch)
    paths.extend(paths_batch)

print(f"first audio sample filename: {paths[0]}")
print(f"Label index: {labels[0]}")
print(f"File name: {file_names[0]}")

test_audios = []
test_labels = []
test_file_names = []
test_paths = []

# For every test folder path, load_and_set_wav_files()
for path in testing_folder_paths:
    audios_batch, labels_batch, sr, file_names_batch, paths_batch = create_waveforms(path)
    test_audios.extend(audios_batch)
    test_labels.extend(labels_batch)
    test_file_names.extend(file_names_batch)
    test_paths.extend(paths_batch)
    
# Test/Training arrays with audio data, label, names, paths.
test_waveform_ds = [test_audios, test_labels, test_file_names, test_paths]
waveform_ds = [audios, labels, file_names, paths]
# Out:
# shaping all audios to length 64000
# Label: 0, Original Shape: (36044,) Fixed Shape: (64000,), Total fixed: 180
# Label: 1, Original Shape: (44360,) Fixed Shape: (64000,), Total fixed: 180
# Label: 2, Original Shape: (43243,) Fixed Shape: (64000,), Total fixed: 180
# Label: 3, Original Shape: (33215,) Fixed Shape: (64000,), Total fixed: 180
# Label: 4, Original Shape: (27600,) Fixed Shape: (64000,), Total fixed: 180
# Label: 5, Original Shape: (50719,) Fixed Shape: (64000,), Total fixed: 180
# Label: 6, Original Shape: (34552,) Fixed Shape: (64000,), Total fixed: 180
# Label: 7, Original Shape: (31999,) Fixed Shape: (64000,), Total fixed: 180
# first audio sample filename: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Am\Am_001.wav
# Label index: 0
# File name: Am_001.wav
# Label: 0, Original Shape: (73646,) Fixed Shape: (64000,), Total fixed: 40
# Label: 1, Original Shape: (101982,) Fixed Shape: (64000,), Total fixed: 40
# Label: 2, Original Shape: (99196,) Fixed Shape: (64000,), Total fixed: 40
# Label: 3, Original Shape: (98638,) Fixed Shape: (64000,), Total fixed: 40
# Label: 4, Original Shape: (109041,) Fixed Shape: (64000,), Total fixed: 40
# Label: 5, Original Shape: (71889,) Fixed Shape: (64000,), Total fixed: 40
# Label: 6, Original Shape: (99939,) Fixed Shape: (64000,), Total fixed: 40
# Label: 7, Original Shape: (98638,) Fixed Shape: (64000,), Total fixed: 40

# %%
test_count = 0
count = 0

audio_samples = random.sample(range(len(audios)), 2)

for i in audio_samples:
    count +=1
    print(f"Path: {paths[i]}, Label: {labels[i]}, File: {file_names[i]}, Shape: {tf.shape(audios[i])}")

print("\n")
Test_audio_samples = random.sample(range(len(test_audios)), 2)

for k in Test_audio_samples:
    test_count += 1
    print(f"Path: {test_paths[k]}, Label: {test_labels[k]}, File: {test_file_names[k]}, Shape: {tf.shape(test_audios[k])}")

print("\n")
print("Test Total: ", len(audios))
print("Train total: ", len(test_audios))
# Out:
# Path: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Bb\Bb_081.wav, Label: 1, File: Bb_081.wav, Shape: [64000]
# Path: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Training\Dm\Dm_028.wav, Label: 4, File: Dm_028.wav, Shape: [64000]
#
#
# Path: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Am\Am_002.wav, Label: 0, File: Am_002.wav, Shape: [64000]
# Path: C:\Users\shane\Documents\GitHub\Chord_App\audio_data\data\Test\Am\Am_036.wav, Label: 0, File: Am_036.wav, Shape: [64000]
#
#
# Test Total:  1440
# Train total:  320

# %% [markdown]
# # Plot Waveforms

# %%
import random

training_samples = random.sample(range(len(audios)), 5)

for i in training_samples:
    plot_title = (f"File: {file_names[i]} Chord: {index_to_label.get(labels[i])}")
    plt.figure(figsize=(10, 3))
    plt.plot(audios[i])
    plt.title(plot_title)
    plt.xlabel("TimeSample")
    plt.ylabel("Amplitude")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# shape gives audio structure, This is a 1D array, so only has (1,)
print("audio 1 shape: ", tf.shape(audios[0]))
# Out:
# audio 1 shape:  tf.Tensor([64000], shape=(1,), dtype=int32)

# %%
def convert_to_spectrogram(waveform):
    # Ensure waveform is a 1D tensor, data type float32
    waveform = tf.cast(waveform, dtype=tf.float32)
    waveform = tf.reshape(waveform, [-1])
    spectrogram = tf.signal.stft(
        waveform,
        # Each frame collect 400 /16000 (25ms of data)
        frame_length=400,
        # 160 / 16000 = (10ms) gap between frames captured
        frame_step=160,
        # Alters Frequency/time resolutions, depending on size
        fft_length=512
    )
    # Increase decibels of spectrogram for better visualization
    spectrogram = tf.abs(spectrogram) ** 2
    spectrogram_db = 10 * tf.math.log(spectrogram + 1e-10) / tf.math.log(10.0)
    # transpose to (freq, time)
    spectrogram_db = tf.transpose(spectrogram_db)
    return spectrogram_db

def plot_spectrograms(spectrogram_ds):
    rows = 3
    cols = 3
    n = rows * cols # 9 Specs

    fig, axes = plt.subplots(rows, cols, figsize=(12, 4))
    axes = axes.flat  # flatten from 2D to 1D
    for i, (spectrogram, label_index) in enumerate(spectrogram_ds[:n]):
        ax = axes[i]
        # transpose to shape shape the diagram
        ax.imshow(tf.transpose(spectrogram).numpy(), aspect='auto', origin='lower', cmap='magma')
        ax.set_title(index_to_label[label_index])
        ax.axis('off')
    plt.tight_layout()
    plt.show()

############ TRAINING Collect all spectrograms and labels to be sent to plot_spectrogram()

audios, labels, file_names, paths = waveform_ds
spectrogram_ds = []
# arrays for training spectrograms
X = []
Y = []

for waveform, label_index in zip(audios, labels):
    spectrogram = convert_to_spectrogram(waveform)
    #prep spectrograms for training
    X.append(spectrogram)
    Y.append(label_index)
    spectrogram_ds.append((spectrogram, label_index))
    
X = tf.stack(X)
# Shape X for num_samples, freq_bins, time_frames, add another dimension
X = tf.expand_dims(X, -1)
Y = tf.convert_to_tensor(Y)

# plot a grid of spectrograms
random_specs = random.sample(range(len(spectrogram_ds)), 9)

sample_specs = [spectrogram_ds[i] for i in random_specs]
plot_spectrograms(sample_specs)

############ TESTING Collect all spectrograms and labels to be sent to plot_spectrogram()
#waveform_ds = []

test_audios, test_labels, test_file_names, test_paths = test_waveform_ds
test_spectrogram_ds = []
# arrays for training

test_X = []
test_Y = []

for waveform, label_index in zip(test_audios, test_labels):
    test_spectrogram = convert_to_spectrogram(waveform)
    #prep spectrograms for training
    test_X.append(test_spectrogram)
    test_Y.append(label_index)
    test_spectrogram_ds.append((test_spectrogram, label_index))

test_X = tf.stack(test_X)
# Shape X for num_samples, freq_bins, time_frames, add another dimension
test_X = tf.expand_dims(test_X, -1)
test_Y = tf.convert_to_tensor(test_Y)

# Display a grid of spectrograms
test_random_specs = random.sample(range(len(test_spectrogram_ds)), 9)
test_sample_specs = [test_spectrogram_ds[i] for i in test_random_specs]

plot_spectrograms(test_sample_specs)

# %%
# ------------------- FIGURES ------------------------

print(f"target_len = 64000 (Length of waveform)")

print(f"frame_length = 400 (Window size for each STFT frame(Chunk of analyzed data))")
print(f"frame_step = 160 (Hop size between STFT window samples)")
print(f"fft_length = 512 (Resolution of feq analysis (Must be less than or equal to frame_length))")



print("\n")
print("Time_Frames = 1 + (target_len - fft_length) // frame_step == 397")
print("Freq_bins = fft_length // 2 + 1 = 171")
print("Batch_size = number of samples.")
print("\n")

print("Spectrogram shape = (freq_bins, time_frames, extra_dims)")

print("Final spectrogram shape = (batch_size, freq_bins, time_frames, extra_dims)")

print("\n")
print("Testing dataset and label dimensions: ")
print("Test Spec dataset shape: ", np.array(test_X).shape)

print("\nTraining dataset and label dimensions: ")
print("Spec dataset shape: ", np.array(X).shape)
# Out:
# target_len = 64000 (Length of waveform)
# frame_length = 400 (Window size for each STFT frame(Chunk of analyzed data))
# frame_step = 160 (Hop size between STFT window samples)
# fft_length = 512 (Resolution of feq analysis (Must be less than or equal to frame_length))
#
#
# Time_Frames = 1 + (target_len - fft_length) // frame_step == 397
# Freq_bins = fft_length // 2 + 1 = 171
# Batch_size = number of samples.
#
#
# Spectrogram shape = (freq_bins, time_frames, extra_dims)
# Final spectrogram shape = (batch_size, freq_bins, time_frames, extra_dims)
#
#
# Testing dataset and label dimensions:
# Test Spec dataset shape:  (320, 257, 398, 1)
#
# Training dataset and label dimensions:
# Spec dataset shape:  (1440, 257, 398, 1)

# %% [markdown]
# # Convolution Neural Network Model training

# %%
# Tensorflow does not allow direct indexing of tensors (X), so convert to array:

X_np = X.numpy()
Y_np = Y.numpy()

print(X_np.shape)
print(Y_np.shape)
# Out:
# (1440, 257, 398, 1)
# (1440,)

# %%
# Create a validation set from splitting the training set to validate the model

X_train, X_test, y_train, y_test = train_test_split(
    X_np,Y_np, test_size=0.2, random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1152, 257, 398, 1)
# (288, 257, 398, 1)

# %% [markdown]
# # Fit model

# %%
## IMPORTED AT TOP: from tensorflow.keras import layers, models

#Input shape to match spectrogram dimensions, 1 is greyscale
# frame length = 256
# frame step = 129
# number of time frames = 1 + (length - frmae_length) // frame_Step ==
# 1 + (64000 - 256) / 128
# Resulting in: 1 + (64000 - 256) / 499 = 

input_shape = (257, 398, 1)

# Fit the state of the layer to the spectrograms

model = models.Sequential([
    layers.Input(shape=input_shape),
    # 16 filters, 3X3 kernel, relu activation function
    layers.Conv2D(16, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    
    layers.Conv2D(32, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    
    layers.Conv2D(128, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2,2)),
    
    layers.GlobalAveragePooling2D(),
    # Dense
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(8, activation='softmax')
    ])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 255, 396, 16)        │             160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 198, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 196, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 62, 98, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 60, 96, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 30, 48, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 28, 46, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 14, 23, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 128)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │           2,056 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 132,232 (516.53 KB)
#  Trainable params: 132,232 (516.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy'],
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Epochs are how many times to model passes the dataset
EPOCHS = 15
## DATA - training sets, test sets, size of test, callback in event of error
## EarlyStopping eith patience=6 if no improvement is seen in epochs
## restore_best_weights = roll back to best epoch
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    callbacks=EarlyStopping(monitor='val_loss', verbose=1, patience=3, restore_best_weights=True),
)
# Out:
# Epoch 1/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 96s 2s/step - accuracy: 0.1361 - loss: 3.0025 - val_accuracy: 0.1215 - val_loss: 2.0750
# Epoch 2/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.1270 - loss: 2.0845 - val_accuracy: 0.1042 - val_loss: 2.0784
# Epoch 3/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.1674 - loss: 2.0743 - val_accuracy: 0.1667 - val_loss: 2.0731
# Epoch 4/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 86s 2s/step - accuracy: 0.1512 - loss: 2.0713 - val_accuracy: 0.1667 - val_loss: 2.0647
# Epoch 5/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - accuracy: 0.1671 - loss: 2.0626 - val_accuracy: 0.2882 - val_loss: 1.9617
# Epoch 6/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - accuracy: 0.2638 - loss: 1.9344 - val_accuracy: 0.3715 - val_loss: 1.6110
# Epoch 7/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - accuracy: 0.4207 - loss: 1.5606 - val_accuracy: 0.7361 - val_loss: 1.0440
# Epoch 8/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.6048 - loss: 1.1447 - val_accuracy: 0.7222 - val_loss: 0.7705
# Epoch 9/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.7110 - loss: 0.8514 - val_accuracy: 0.8333 - val_loss: 0.5346
# Epoch 10/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.7795 - loss: 0.6618 - val_accuracy: 0.8681 - val_loss: 0.4700
# Epoch 11/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.8068 - loss: 0.5420 - val_accuracy: 0.8646 - val_loss: 0.4217
# Epoch 12/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.8506 - loss: 0.4697 - val_accuracy: 0.8785 - val_loss: 0.3307
# Epoch 13/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 89s 2s/step - accuracy: 0.8820 - loss: 0.3556 - val_accuracy: 0.9097 - val_loss: 0.3073
# Epoch 14/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 88s 2s/step - accuracy: 0.9005 - loss: 0.2865 - val_accuracy: 0.9236 - val_loss: 0.2422
# Epoch 15/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.8866 - loss: 0.3313 - val_accuracy: 0.8958 - val_loss: 0.3734
# Restoring model weights from the end of the best epoch: 14.

# %%
metrics = history.history
plt.plot(history.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.show()

plt.plot(history.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.show()

# Accuracy over each Epoch improves over time, then plataus. Early stopping

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred_probs = model.predict(X_test)
y_pred = tf.argmax(y_pred_probs, axis=1).numpy()
y_true = y_test

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=list(label_to_index.keys()))
disp.plot(cmap='magma',
          xticks_rotation=45)
plt.title=("Confusion Matrix")
plt.show()
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 558ms/step

# %%
print("y_test shape: ", y_test.shape)
# shape of y_pred_probs is numbder of samples, and number of classes (8 labels)
print("y_pred_probs shape: ", y_pred_probs.shape)
# shows percentages of probability for each class of chord
print("y_pred_probs[0]: ",y_pred_probs[0])
# Out:
# y_test shape:  (288,)
# y_pred_probs shape:  (288, 8)
# y_pred_probs[0]:  [0.6307781  0.01630633 0.00114151 0.21511404 0.02996278 0.08582947
#  0.01452647 0.00634124]

# %%
#model.save('models/chord_model_64.h5')

# %%
print(os.getcwd())
# Out:
# C:\Users\shane\Documents\GitHub\Chord_App\notebooks
